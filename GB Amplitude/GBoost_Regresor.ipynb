# %%
#files
import sys
#from os import listdir
sys.path.append('../data')
sys.path.append('../Librerias')
#from os.path import isfile, join

#own libs
import utils
import caract as dc
import dataset as ds
from models import SimpleRNN, LSTM
#from lstm_models import LSTM
import utils_2 as ut2
from traindata import trainData



#data and visualization
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import HistGradientBoostingRegressor, GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import PredefinedSplit
from sklearn.model_selection import GridSearchCV

sns.set_style("darkgrid")


import numpy as np
from tqdm import tqdm



np.random.seed(seed=77)

# %% [markdown]
# ## **data**

# %%
#fpath = "/Users/consu/OneDrive/Documentos/GitHub/Tesis/data/low/"
#fpath = "/Users/granosftp/Documents/GitHub/Tesis/data/low/"
fpath = '/Users/consuelo/Documents/GitHub/Tesis/data/low/'
fname = "file1_080124.mat"
#cutoff = [8/1000, 11/1000]

data = trainData(fpath, fname, 'Amplitude')
train, val, test = data.split_data('Amplitude')
# Out:
# 0         0.006094
# 1         0.006132
# 2         0.006056
# 3         0.006018
# 4         0.006170
#             ...
# 599995    0.007766
# 599996    0.007741
# 599997    0.007761
# 599998    0.007748
# 599999    0.007755
# Name: Amplitude, Length: 600000, dtype: float64
# 0         0.006094
# 1         0.006132
# 2         0.006056
# 3         0.006018
# 4         0.006170
#             ...
# 599995    0.007766
# 599996    0.007741
# 599997    0.007761
# 599998    0.007748
# 599999    0.007755
# Name: Amplitude, Length: 600000, dtype: float64
# 0         0.006094
# 1         0.006132
# 2         0.006056
# 3         0.006018
# 4         0.006170
#             ...
# 599995    0.007766
# 599996    0.007741
# 599997    0.007761
# 599998    0.007748
# 599999    0.007755
# Name: Amplitude, Length: 600000, dtype: float64
# 0         0.006094
# 1         0.006132
# 2         0.006056
# 3         0.006018
# 4         0.006170
#             ...
# 599995    0.007766
# 599996    0.007741
# 599997    0.007761
# 599998    0.007748
# 599999    0.007755
# Name: Amplitude, Length: 600000, dtype: float64

# %%
# sub sampleo

train = utils.subsample(train, 2)
val = utils.subsample(val, 2)
test = utils.subsample(test, 2)

# %%
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train.reshape(-1, 1))
val_scaled = scaler.transform(val.reshape(-1, 1))
test_scaled = scaler.transform(test.reshape(-1, 1))

# %%
x_train, y_train = ut2.create_sequences(train_scaled, 1000, 1)
x_train = x_train.squeeze()
y_train = y_train.squeeze()

x_val, y_val = ut2.create_sequences(val_scaled, 1000, 1)
x_val = x_val.squeeze()
y_val = y_val.squeeze()

x_test, y_test = ut2.create_sequences(test_scaled[:3000], 1000, 1)
x_test = x_test.squeeze()
y_test = y_test.squeeze()

x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((209000, 1000), (209000,), (44000, 1000), (44000,), (2000, 1000), (2000,))

# %% [markdown]
# ## **Gradient Boosting**

# %%
'''model = HistGradientBoostingRegressor()
param = {'learning_rate': [0.001, 0.01, 0.1],
         'loss': ['squared_error', 'absolute_error', 'gamma', 'poisson'],
         'min_samples_leaf': [10, 20, 30],
         'scoring' : ['neg_mean_squared_error', 'neg_mean_percentage_absolute_error', 'neg_mean_absolute_error']
         }'''
# Out:
# "model = HistGradientBoostingRegressor()\nparam = {'learning_rate': [0.001, 0.01, 0.1],\n         'loss': ['squared_error', 'absolute_error', 'gamma', 'poisson'],\n         'min_samples_leaf': [10, 20, 30],\n         'scoring' : ['neg_mean_squared_error', 'neg_mean_percentage_absolute_error', 'neg_mean_absolute_error']\n         }"

# %%
model = GradientBoostingRegressor()

param = {'n_estimators': [10, 50, 100],
         'learning_rate': [0.001, 0.01, 0.1],
         'subsample': [0.5, 0.7, 1.0],
         'max_depth': [3, 7, 9]
         }

# %%
test_fold = [-1 for _ in range(x_train[:5000].shape[0])] + [0 for _ in range(x_val[:3000].shape[0])]
ps = PredefinedSplit(test_fold)

#concateno matrices de training y validación
xTrainVal = np.concatenate((x_train[:5000],x_val[:3000]),axis=0)
yTrainVal = np.concatenate((y_train[:5000],y_val[:3000]),axis = 0)


grid=GridSearchCV(model, param, n_jobs = -1, verbose = 2)
grid.fit(xTrainVal,yTrainVal)

print('Mejor Estimator: ', grid.best_estimator_)
print('Mejores Parametros: ', grid.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, subsample=0.5; total time=   9.0s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, subsample=0.5; total time=   9.1s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, subsample=0.5; total time=   9.1s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, subsample=0.5; total time=   9.3s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, subsample=0.5; total time=   9.7s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, subsample=0.7; total time=  13.0s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, subsample=0.7; total time=  13.2s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, subsample=0.7; total time=  13.2s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, subsample=0.7; total time=  13.4s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, subsample=0.7; total time=  13.4s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, subsample=1.0; total time=  19.9s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, subsample=1.0; total time=  20.0s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, subsample=1.0; total time=  20.3s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, subsample=1.0; total time=  20.4s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, subsample=1.0; total time=  20.6s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=50, subsample=0.5; total time=  46.6s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=50, subsample=0.5; total time=  46.9s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=50, subsample=0.5; total time=  47.0s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=50, subsample=0.5; total time=  47.3s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=50, subsample=0.5; total time=  47.9s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=50, subsample=0.7; total time= 1.1min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=50, subsample=0.7; total time= 1.1min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=50, subsample=0.7; total time= 1.1min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=50, subsample=0.7; total time= 1.1min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=50, subsample=0.7; total time= 1.1min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=50, subsample=1.0; total time= 1.6min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=50, subsample=1.0; total time= 1.6min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=50, subsample=1.0; total time= 1.6min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=50, subsample=1.0; total time= 1.6min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=50, subsample=1.0; total time= 1.6min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, subsample=0.7; total time= 2.1min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, subsample=0.7; total time= 2.1min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, subsample=0.7; total time= 2.1min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=10, subsample=0.5; total time=  18.5s
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=10, subsample=0.5; total time=  18.4s
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=10, subsample=0.5; total time=  18.5s
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=10, subsample=0.5; total time=  18.2s
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=10, subsample=0.5; total time=  19.1s
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=10, subsample=0.7; total time=  26.6s
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=10, subsample=0.7; total time=  26.4s
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=10, subsample=0.7; total time=  26.3s
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=10, subsample=0.7; total time=  26.7s
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=10, subsample=0.7; total time=  26.6s
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=10, subsample=1.0; total time=  39.0s
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=10, subsample=1.0; total time=  39.1s
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=10, subsample=1.0; total time=  39.7s
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=10, subsample=1.0; total time=  39.8s
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=10, subsample=1.0; total time=  39.3s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, subsample=1.0; total time= 3.1min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, subsample=1.0; total time= 3.2min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, subsample=1.0; total time= 3.2min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, subsample=1.0; total time= 3.2min
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, subsample=1.0; total time= 3.2min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=50, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=50, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=50, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=50, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=50, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=50, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=50, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=50, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=50, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=50, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=50, subsample=1.0; total time= 3.2min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=50, subsample=1.0; total time= 3.2min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=50, subsample=1.0; total time= 3.3min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=50, subsample=1.0; total time= 3.3min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=50, subsample=1.0; total time= 3.3min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=100, subsample=0.5; total time= 3.0min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=100, subsample=0.5; total time= 3.0min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=100, subsample=0.5; total time= 3.0min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=100, subsample=0.5; total time= 3.1min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=100, subsample=0.5; total time= 3.1min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=100, subsample=0.7; total time= 4.5min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=100, subsample=0.7; total time= 4.5min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=100, subsample=0.7; total time= 4.5min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=100, subsample=0.7; total time= 4.5min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=100, subsample=0.7; total time= 4.5min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=10, subsample=0.5; total time=  21.7s
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=10, subsample=0.5; total time=  21.6s
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=10, subsample=0.5; total time=  21.6s
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=10, subsample=0.5; total time=  22.4s
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=10, subsample=0.5; total time=  22.6s
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=10, subsample=0.7; total time=  31.8s
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=10, subsample=0.7; total time=  31.6s
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=10, subsample=0.7; total time=  31.9s
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=10, subsample=0.7; total time=  31.8s
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=10, subsample=0.7; total time=  31.7s
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=10, subsample=1.0; total time=  48.4s
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=10, subsample=1.0; total time=  48.4s
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=10, subsample=1.0; total time=  49.1s
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=10, subsample=1.0; total time=  48.8s
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=10, subsample=1.0; total time=  48.3s
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=100, subsample=1.0; total time= 6.6min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=100, subsample=1.0; total time= 6.6min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=100, subsample=1.0; total time= 6.6min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=100, subsample=1.0; total time= 6.6min
# [CV] END learning_rate=0.001, max_depth=7, n_estimators=100, subsample=1.0; total time= 6.8min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=50, subsample=0.5; total time= 1.8min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=50, subsample=0.5; total time= 1.8min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=50, subsample=0.5; total time= 1.8min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=50, subsample=0.5; total time= 1.8min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=50, subsample=0.5; total time= 1.8min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=50, subsample=0.7; total time= 2.6min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=50, subsample=0.7; total time= 2.6min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=50, subsample=0.7; total time= 2.7min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=50, subsample=0.7; total time= 2.7min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=50, subsample=0.7; total time= 2.7min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=50, subsample=1.0; total time= 3.9min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=50, subsample=1.0; total time= 3.9min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=50, subsample=1.0; total time= 4.0min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=50, subsample=1.0; total time= 3.9min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=50, subsample=1.0; total time= 4.0min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=100, subsample=0.5; total time= 3.7min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=100, subsample=0.5; total time= 3.7min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=100, subsample=0.5; total time= 3.7min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=100, subsample=0.5; total time= 3.8min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=100, subsample=0.5; total time= 3.7min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=100, subsample=0.7; total time=45.0min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=100, subsample=0.7; total time=44.9min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=100, subsample=0.7; total time=45.0min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.5; total time=  10.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.5; total time=  10.5s
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=100, subsample=0.7; total time=45.0min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=100, subsample=0.7; total time=45.0min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.5; total time=  11.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.5; total time=  11.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.5; total time=  11.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.7; total time=  16.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.7; total time=  16.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.7; total time= 1.0min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.7; total time= 1.0min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, subsample=0.7; total time= 1.0min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1.0; total time= 1.1min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1.0; total time= 1.1min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1.0; total time=  19.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1.0; total time=  19.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, subsample=1.0; total time=  19.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=  46.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=  47.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=  46.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=  47.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=  47.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time= 1.1min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time= 1.1min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time= 1.1min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time= 1.1min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time= 1.1min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=100, subsample=1.0; total time=48.4min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=100, subsample=1.0; total time=48.4min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time= 1.5min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time= 1.6min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=100, subsample=1.0; total time=48.5min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time= 1.6min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time= 1.6min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time= 1.5min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=100, subsample=1.0; total time=48.5min
# [CV] END learning_rate=0.001, max_depth=9, n_estimators=100, subsample=1.0; total time=48.6min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time= 1.4min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time= 2.1min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time= 2.1min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time= 2.1min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=10, subsample=0.5; total time=  18.0s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=10, subsample=0.5; total time=  17.8s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=10, subsample=0.5; total time=  17.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time= 2.1min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time= 2.1min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=10, subsample=0.5; total time=  18.1s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=10, subsample=0.5; total time=  17.8s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=10, subsample=0.7; total time=  25.8s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=10, subsample=0.7; total time=  25.5s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=10, subsample=0.7; total time=  27.0s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=10, subsample=0.7; total time=  26.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=10, subsample=0.7; total time=  26.3s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=10, subsample=1.0; total time=  38.5s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=10, subsample=1.0; total time=  39.0s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=10, subsample=1.0; total time=  39.1s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=10, subsample=1.0; total time=  39.4s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=10, subsample=1.0; total time=  39.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time= 3.1min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time= 3.1min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time= 3.1min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time= 3.1min
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time= 3.1min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.7; total time= 2.3min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0; total time= 3.3min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0; total time= 3.3min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0; total time= 3.3min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0; total time= 3.3min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0; total time= 3.3min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time= 3.0min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time= 3.0min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time= 3.0min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time= 3.0min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.5; total time= 3.1min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7; total time= 4.4min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7; total time= 4.4min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7; total time= 4.4min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7; total time= 4.4min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7; total time= 4.4min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=10, subsample=0.5; total time=  22.9s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=10, subsample=0.5; total time=  22.0s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=10, subsample=0.5; total time=  22.0s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=10, subsample=0.5; total time=  21.9s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=10, subsample=0.5; total time=  22.2s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=10, subsample=0.7; total time=  31.7s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=10, subsample=0.7; total time=  33.1s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=10, subsample=0.7; total time=  32.6s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=10, subsample=0.7; total time=  33.2s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=10, subsample=0.7; total time=  33.3s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=10, subsample=1.0; total time=  48.2s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=10, subsample=1.0; total time=  48.7s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=10, subsample=1.0; total time=  47.8s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=10, subsample=1.0; total time=  48.4s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=10, subsample=1.0; total time=  48.5s
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time= 6.5min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time= 6.5min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time= 6.6min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time= 6.6min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.5; total time= 1.9min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.5; total time= 1.9min
# [CV] END learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0; total time= 6.6min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.5; total time= 1.9min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.5; total time= 1.9min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.5; total time= 1.9min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.7; total time= 2.7min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.7; total time= 2.7min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.7; total time= 2.7min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.7; total time= 2.7min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=0.7; total time= 2.7min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=1.0; total time= 4.0min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=1.0; total time= 4.1min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=1.0; total time= 4.0min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=1.0; total time= 4.0min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=50, subsample=1.0; total time= 4.0min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.5; total time= 4.6min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.5; total time= 4.6min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.5; total time= 4.6min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.5; total time= 4.6min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.5; total time= 4.6min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.7; total time= 6.3min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.7; total time= 6.3min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.7; total time= 6.2min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.5; total time=   9.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.5; total time=   9.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.5; total time=   9.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.5; total time=   9.2s
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.7; total time= 6.3min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=0.7; total time= 6.3min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.5; total time=   9.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.7; total time=  13.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.7; total time=  13.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.7; total time=  13.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.7; total time=  13.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, subsample=0.7; total time=  13.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, subsample=1.0; total time=  19.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, subsample=1.0; total time=  19.7s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, subsample=1.0; total time=  19.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, subsample=1.0; total time=  19.7s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, subsample=1.0; total time=  19.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=  45.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=  45.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=  44.9s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=  44.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=  45.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.7; total time= 1.1min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.7; total time= 1.1min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.7; total time= 1.1min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.7; total time= 1.1min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.7; total time= 1.1min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time= 3.5min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time= 3.5min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time= 3.5min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time= 3.5min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time= 3.5min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=1.0; total time= 9.8min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=1.0; total time= 9.9min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=1.0; total time= 9.9min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=1.0; total time= 9.9min
# [CV] END learning_rate=0.01, max_depth=9, n_estimators=100, subsample=1.0; total time= 9.9min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time= 1.6min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time= 1.6min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time= 1.6min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=10, subsample=0.5; total time=  18.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=10, subsample=0.5; total time=  17.9s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=10, subsample=0.5; total time=  18.0s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=10, subsample=0.5; total time=  17.9s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=10, subsample=0.5; total time=  18.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=10, subsample=0.7; total time=  26.3s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=10, subsample=0.7; total time=  25.9s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=10, subsample=0.7; total time=  26.0s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=10, subsample=0.7; total time=  26.1s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=10, subsample=0.7; total time=  26.2s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=10, subsample=1.0; total time=  38.8s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=10, subsample=1.0; total time=  38.7s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=10, subsample=1.0; total time=  38.6s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=10, subsample=1.0; total time=  38.9s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=10, subsample=1.0; total time=  38.8s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time= 3.1min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time= 3.2min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time= 3.2min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time= 3.2min
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time= 3.2min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.5; total time= 1.5min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.5; total time= 1.6min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.5; total time= 1.6min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=50, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=50, subsample=1.0; total time= 3.3min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=50, subsample=1.0; total time= 3.3min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=50, subsample=1.0; total time= 3.3min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=50, subsample=1.0; total time= 3.3min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=50, subsample=1.0; total time= 3.3min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time= 3.2min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time= 3.2min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time= 3.2min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time= 3.2min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.5; total time= 3.2min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7; total time= 4.7min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7; total time= 4.7min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7; total time= 4.7min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7; total time= 4.6min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7; total time= 4.7min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=10, subsample=0.5; total time=  22.4s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=10, subsample=0.5; total time=  22.0s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=10, subsample=0.5; total time=  22.1s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=10, subsample=0.5; total time=  22.2s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=10, subsample=0.5; total time=  22.7s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=10, subsample=0.7; total time=  32.2s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=10, subsample=0.7; total time=  32.2s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=10, subsample=0.7; total time=  32.3s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=10, subsample=0.7; total time=  32.4s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=10, subsample=0.7; total time=  32.1s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=10, subsample=1.0; total time=  47.7s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=10, subsample=1.0; total time=  47.0s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=10, subsample=1.0; total time=  47.1s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=10, subsample=1.0; total time=  47.3s
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=10, subsample=1.0; total time=  48.3s
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time= 7.9min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time= 8.0min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time= 8.0min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=0.5; total time= 3.0min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=0.5; total time= 3.0min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time= 8.1min
# [CV] END learning_rate=0.1, max_depth=7, n_estimators=100, subsample=1.0; total time= 8.0min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=0.5; total time= 3.0min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=0.5; total time= 3.0min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=0.5; total time= 3.0min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=0.7; total time= 2.7min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=0.7; total time= 2.7min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=0.7; total time= 2.7min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=0.7; total time= 2.7min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=0.7; total time= 2.7min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=1.0; total time= 4.0min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=1.0; total time= 4.0min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=1.0; total time= 4.0min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=1.0; total time= 4.0min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=50, subsample=1.0; total time= 4.0min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=0.5; total time= 4.0min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=0.5; total time= 3.9min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=0.5; total time= 4.0min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=0.5; total time= 3.9min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=0.5; total time= 4.0min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=0.7; total time= 5.6min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=0.7; total time= 5.6min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=0.7; total time= 5.6min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=0.7; total time= 5.7min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=0.7; total time= 5.6min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=1.0; total time= 7.4min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=1.0; total time= 7.5min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=1.0; total time= 7.5min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=1.0; total time= 7.5min
# [CV] END learning_rate=0.1, max_depth=9, n_estimators=100, subsample=1.0; total time= 7.5min
# Mejor Estimator:  GradientBoostingRegressor(max_depth=9, n_estimators=50, subsample=0.7)
# Mejores Parametros:  {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 50, 'subsample': 0.7}

# %%
model = grid.best_estimator_

# %%
model.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=9, n_estimators=50, subsample=0.7)

# %%
import pickle
# save the model to disk
filename = 'GBoost_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %% [markdown]
# ## **testeo**

# %%
def rollingWindowPrediction_SVR(model, x_test, steps=50):
    output = []
    N = x_test.shape[-1]

    for elem in tqdm(x_test):
        elem = elem.reshape(1, -1)
        #print(elem)
        test_aux = []
        count = 0
        while count < steps:
            #print(count)
            pred = model.predict(elem)
            test_aux.append(pred[0])
            elem = np.append(elem, pred)[1:].reshape(1,-1)
            #print(elem.shape)
            count += 1

        output.append(test_aux)
    return output

# %%
import pickle
filename = 'GBoost_model.sav'
# load model
model = pickle.load(open(filename, 'rb'))

# %%
test_pred = rollingWindowPrediction_SVR(model, x_test, steps = 50)
# Out:
# 100%|██████████| 2000/2000 [00:06<00:00, 288.23it/s]

# %%
i = 65

plt.plot(test_pred[i],'-+', label='Prediction')
plt.plot(y_test[i:i+50], '-*',label='Real')
plt.legend()
plt.show()
