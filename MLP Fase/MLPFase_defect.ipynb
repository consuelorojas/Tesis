# %%
#files
import sys
#from os import listdir
sys.path.append('../data')
sys.path.append('../Librerias')
#from os.path import isfile, join

#own libs
import utils
import caract as dc
import dataset as ds
from models import SimpleRNN, LSTM, MLP
#from lstm_models import LSTM
import utils_2 as ut2
from traindata import trainData
import errores as er



#data and visualization
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, root_mean_squared_error, r2_score

sns.set_style("darkgrid")


import numpy as np
import random
import os, errno
from tqdm import tqdm

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import torch.utils.data as data_utils


np.random.seed(seed=77)
torch.manual_seed(77)

# %%
fpath = "/Users/consu/OneDrive/Documentos/GitHub/Tesis/data/low/"
#fpath = "/Users/granosftp/Documents/GitHub/Tesis/data/low/"
fname = "file1_080124.mat"
#cutoff = [8/1000, 11/1000]

data = trainData(fpath, fname, 'Gradient Phase')
train, val, test = data.split_data('Gradient Phase')
# Out:
# 0        -0.049881
# 1        -0.037877
# 2        -0.026438
# 3        -0.016091
# 4        -0.007256
#             ...
# 599995   -0.122759
# 599996   -0.131433
# 599997   -0.140539
# 599998   -0.149889
# 599999   -0.159250
# Name: Gradient Phase, Length: 600000, dtype: float64
# 0        -0.049881
# 1        -0.037877
# 2        -0.026438
# 3        -0.016091
# 4        -0.007256
#             ...
# 599995   -0.122759
# 599996   -0.131433
# 599997   -0.140539
# 599998   -0.149889
# 599999   -0.159250
# Name: Gradient Phase, Length: 600000, dtype: float64
# 0        -0.049881
# 1        -0.037877
# 2        -0.026438
# 3        -0.016091
# 4        -0.007256
#             ...
# 599995   -0.122759
# 599996   -0.131433
# 599997   -0.140539
# 599998   -0.149889
# 599999   -0.159250
# Name: Gradient Phase, Length: 600000, dtype: float64
# 0        -0.049881
# 1        -0.037877
# 2        -0.026438
# 3        -0.016091
# 4        -0.007256
#             ...
# 599995   -0.122759
# 599996   -0.131433
# 599997   -0.140539
# 599998   -0.149889
# 599999   -0.159250
# Name: Gradient Phase, Length: 600000, dtype: float64

# %%
import copy

train = utils.subsample(train, 2)
test = utils.subsample(test, 2)

scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train.reshape(-1, 1))
#test = copy.deepcopy(test_scaled)

# %%
amplitude = data.data['Gradient Phase'].values
amplitude = scaler.transform(amplitude.reshape(-1, 1))
defectos = data.defectos_set()

# %%
in_size = 1000
out_size = 1
hid_size = 500
num_layers = 2

model = MLP(in_size, hid_size, out_size)
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()

utils.resume(model, optimizer, 'earlystop_93.pth')

# %% [markdown]
# ## **50 steps**

# %%
steps = 50 
x_test, y_test = ut2.defectos_set(defectos, amplitude, steps*2, horizon = 2000)

x_test = [utils.subsample(elem,2) for elem in x_test]
x_test = np.array(x_test)

y_test = [utils.subsample(elem,2) for elem in y_test]
y_test = np.array(y_test)


x_test = torch.from_numpy(x_test.astype(np.float32)).squeeze()
y_test = torch.from_numpy(y_test.astype(np.float32)).squeeze()

x_test.shape, y_test.shape
# Out:
# (torch.Size([95, 1000]), torch.Size([95, 50]))

# %%
test50 = ut2.rollingWindowPrediction(model,x_test,steps)
np.savetxt("test50_MLP_defectosFase.csv", test50, delimiter=",")
# Out:
# 100%|██████████| 95/95 [00:01<00:00, 49.28it/s]

# %%
mse, mape, r2, rmse = er.calculate_errors(test50, y_test)
print(f'Mean Squared Error: {mse}')
print(f'Mean Absolute Percentage Error: {mape}')
print(f'R2 Score: {r2}')
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Mean Squared Error: 0.01575109613198089
# Mean Absolute Percentage Error: 0.9284261576195392
# R2 Score: -0.9711465338605515
# Root Mean Squared Error: 0.05614691281734112

# %%
i = 10
plt.plot(y_test[i], 'o-',label='Real')
plt.plot(test50[i], '*-',label='Prediction')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

# %% [markdown]
# ## **100 steps**

# %%
steps = 100 
x_test, y_test = ut2.defectos_set(defectos, amplitude, steps*2, horizon = 2000)

x_test = [utils.subsample(elem,2) for elem in x_test]
x_test = np.array(x_test)

y_test = [utils.subsample(elem,2) for elem in y_test]
y_test = np.array(y_test)


x_test = torch.from_numpy(x_test.astype(np.float32)).squeeze()
y_test = torch.from_numpy(y_test.astype(np.float32)).squeeze()

x_test.shape, y_test.shape
# Out:
# (torch.Size([95, 1000]), torch.Size([95, 100]))

# %%
test100 = ut2.rollingWindowPrediction(model,x_test,steps)
np.savetxt("test100_MLP_defectosFase.csv", test100, delimiter=",")
# Out:
# 100%|██████████| 95/95 [00:04<00:00, 23.61it/s]

# %%
mse, mape, r2, rmse = er.calculate_errors(test100, y_test)
print(f'Mean Squared Error: {mse}')
print(f'Mean Absolute Percentage Error: {mape}')
print(f'R2 Score: {r2}')
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Mean Squared Error: 0.009704091822951134
# Mean Absolute Percentage Error: 0.5056958574936585
# R2 Score: -0.5253227488075126
# Root Mean Squared Error: 0.0570455000409817

# %%
i = -1
plt.plot(y_test[i], 'o-',label='Real')
plt.plot(test100[i], '*-',label='Prediction')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

# %% [markdown]
# ## **500 steps**

# %%
steps = 500 
x_test, y_test = ut2.defectos_set(defectos, amplitude, steps*2, horizon = 2000)

x_test = [utils.subsample(elem,2) for elem in x_test]
x_test = np.array(x_test)

y_test = [utils.subsample(elem,2) for elem in y_test]
y_test = np.array(y_test)


x_test = torch.from_numpy(x_test.astype(np.float32)).squeeze()
y_test = torch.from_numpy(y_test.astype(np.float32)).squeeze()

x_test.shape, y_test.shape
# Out:
# (torch.Size([95, 1000]), torch.Size([95, 500]))

# %%
test500 = ut2.rollingWindowPrediction(model,x_test,steps)
np.savetxt("test500_MLP_defectosFase.csv", test500, delimiter=",")
# Out:
# 100%|██████████| 95/95 [00:19<00:00,  4.79it/s]

# %%
mse, mape, r2, rmse = er.calculate_errors(test500, y_test)
print(f'Mean Squared Error: {mse}')
print(f'Mean Absolute Percentage Error: {mape}')
print(f'R2 Score: {r2}')
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Mean Squared Error: 0.0044910891383351794
# Mean Absolute Percentage Error: 0.16889635402310682
# R2 Score: -0.1237771734675601
# Root Mean Squared Error: 0.05531865474559879

# %%
i = -1
plt.plot(y_test[i], 'o-',label='Real')
plt.plot(test500[i], '*-',label='Prediction')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

# %% [markdown]
# ## **1000 steps**

# %%
steps = 1000 
x_test, y_test = ut2.defectos_set(defectos, amplitude, steps*2, horizon = 2000)

x_test = [utils.subsample(elem,2) for elem in x_test]
x_test = np.array(x_test)

y_test = [utils.subsample(elem,2) for elem in y_test]
y_test = np.array(y_test)


x_test = torch.from_numpy(x_test.astype(np.float32)).squeeze()
y_test = torch.from_numpy(y_test.astype(np.float32)).squeeze()

x_test.shape, y_test.shape
# Out:
# (torch.Size([95, 1000]), torch.Size([95, 1000]))

# %%
test1000 = ut2.rollingWindowPrediction(model,x_test,steps)
np.savetxt("test1000_MLP_defectosFase.csv", test1000, delimiter=",")
# Out:
# 100%|██████████| 95/95 [00:36<00:00,  2.57it/s]

# %%
mse, mape, r2, rmse = er.calculate_errors(test1000, y_test)
print(f'Mean Squared Error: {mse}')
print(f'Mean Absolute Percentage Error: {mape}')
print(f'R2 Score: {r2}')
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Mean Squared Error: 0.0034970855156847146
# Mean Absolute Percentage Error: 0.12048479398151114
# R2 Score: -0.09674520599950434
# Root Mean Squared Error: 0.05200881579564486

# %%
i = -1
plt.plot(y_test[i], 'o-',label='Real')
plt.plot(test1000[i], '*-',label='Prediction')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()
