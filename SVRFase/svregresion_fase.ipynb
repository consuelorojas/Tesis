# %%
#files
import sys
#from os import listdir
sys.path.append('../data')
sys.path.append('../Librerias')
#from os.path import isfile, join

#own libs
import utils
import caract as dc
import dataset as ds
from models import SimpleRNN, LSTM
#from lstm_models import LSTM
import utils_2 as ut2
from traindata import trainData



#data and visualization
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVR

sns.set_style("darkgrid")


import numpy as np
from tqdm import tqdm



np.random.seed(seed=77)

# %% [markdown]
# ## **data**

# %%
#fpath = "/Users/consu/OneDrive/Documentos/GitHub/Tesis/data/low/"
fpath = "/Users/granosftp/Documents/GitHub/Tesis/data/low/"
fname = "file1_080124.mat"
#cutoff = [8/1000, 11/1000]

data = trainData(fpath, fname, 'Gradient Phase')
train, val, test = data.split_data('Gradient Phase')
# Out:
# 0        -0.049881
# 1        -0.037877
# 2        -0.026438
# 3        -0.016091
# 4        -0.007256
#             ...
# 599995   -0.122759
# 599996   -0.131433
# 599997   -0.140539
# 599998   -0.149889
# 599999   -0.159250
# Name: Gradient Phase, Length: 600000, dtype: float64
# 0        -0.049881
# 1        -0.037877
# 2        -0.026438
# 3        -0.016091
# 4        -0.007256
#             ...
# 599995   -0.122759
# 599996   -0.131433
# 599997   -0.140539
# 599998   -0.149889
# 599999   -0.159250
# Name: Gradient Phase, Length: 600000, dtype: float64
# 0        -0.049881
# 1        -0.037877
# 2        -0.026438
# 3        -0.016091
# 4        -0.007256
#             ...
# 599995   -0.122759
# 599996   -0.131433
# 599997   -0.140539
# 599998   -0.149889
# 599999   -0.159250
# Name: Gradient Phase, Length: 600000, dtype: float64
# 0        -0.049881
# 1        -0.037877
# 2        -0.026438
# 3        -0.016091
# 4        -0.007256
#             ...
# 599995   -0.122759
# 599996   -0.131433
# 599997   -0.140539
# 599998   -0.149889
# 599999   -0.159250
# Name: Gradient Phase, Length: 600000, dtype: float64

# %%
# sub sampleo

train = utils.subsample(train, 2)
val = utils.subsample(val, 2)
test = utils.subsample(test, 2)

# %%
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train.reshape(-1, 1))
val_scaled = scaler.transform(val.reshape(-1, 1))
test_scaled = scaler.transform(test.reshape(-1, 1))

# %%
x_train, y_train = ut2.create_sequences(train_scaled[:50000], 1000, 1)
x_train = x_train.squeeze()
y_train = y_train.squeeze()

x_val, y_val = ut2.create_sequences(val_scaled[:5000], 1000, 1)
x_val = x_val.squeeze()
y_val = y_val.squeeze()

x_test, y_test = ut2.create_sequences(test_scaled[:3000], 1000, 1)
x_test = x_test.squeeze()
y_test = y_test.squeeze()

x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((49000, 1000), (49000,), (4000, 1000), (4000,), (2000, 1000), (2000,))

# %% [markdown]
# ## **modelo svr**

# %%
from sklearn.model_selection import RepeatedKFold, GridSearchCV, cross_validate
from sklearn.feature_selection import SelectKBest, mutual_info_regression
from sklearn.pipeline import Pipeline

# %%
from sklearn.model_selection import PredefinedSplit

model = SVR()
param = {'kernel' : ('linear', 'poly', 'rbf', 'sigmoid'),
         'C' : [1,5,10],
         'degree' : [3,8],
         'coef0' : [0.01,10,0.5],
         'gamma' : ('auto','scale')}

#array para el predefinedsplit
test_fold = [-1 for _ in range(x_train.shape[0])] + [0 for _ in range(x_val.shape[0])]
ps = PredefinedSplit(test_fold)

#concateno matrices de training y validación
xTrainVal = np.concatenate((x_train,x_val),axis=0)
yTrainVal = np.concatenate((y_train,y_val),axis = 0)


grid=GridSearchCV(SVR( ), param, n_jobs = -1, verbose = 2)
grid.fit(xTrainVal,yTrainVal)

print('Mejor Estimator: ', grid.best_estimator_)
print('Mejores Parametros: ', grid.best_params_)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV] END C=1, coef0=0.01, degree=3, gamma=auto, kernel=linear; total time=  13.0s
# [CV] END C=1, coef0=0.01, degree=3, gamma=auto, kernel=linear; total time=  13.5s
# [CV] END C=1, coef0=0.01, degree=3, gamma=auto, kernel=linear; total time=  14.0s
# [CV] END C=1, coef0=0.01, degree=3, gamma=auto, kernel=linear; total time=  14.1s
# [CV] END C=1, coef0=0.01, degree=3, gamma=auto, kernel=linear; total time=  15.4s
# [CV] END ..C=1, coef0=0.01, degree=3, gamma=auto, kernel=rbf; total time=  55.3s
# [CV] END ..C=1, coef0=0.01, degree=3, gamma=auto, kernel=rbf; total time=  57.9s
# [CV] END ..C=1, coef0=0.01, degree=3, gamma=auto, kernel=rbf; total time=  58.2s
# [CV] END .C=1, coef0=0.01, degree=3, gamma=auto, kernel=poly; total time= 1.9min
# [CV] END .C=1, coef0=0.01, degree=3, gamma=auto, kernel=poly; total time= 2.0min
# [CV] END .C=1, coef0=0.01, degree=3, gamma=auto, kernel=poly; total time= 1.9min
# [CV] END ..C=1, coef0=0.01, degree=3, gamma=auto, kernel=rbf; total time=  54.8s
# [CV] END .C=1, coef0=0.01, degree=3, gamma=auto, kernel=poly; total time= 2.1min
# [CV] END ..C=1, coef0=0.01, degree=3, gamma=auto, kernel=rbf; total time=  57.7s
# [CV] END .C=1, coef0=0.01, degree=3, gamma=auto, kernel=poly; total time= 2.0min
# [CV] END C=1, coef0=0.01, degree=3, gamma=scale, kernel=linear; total time=  11.4s
# [CV] END C=1, coef0=0.01, degree=3, gamma=scale, kernel=linear; total time=  13.2s
# [CV] END C=1, coef0=0.01, degree=3, gamma=scale, kernel=linear; total time=  10.8s
# [CV] END C=1, coef0=0.01, degree=3, gamma=auto, kernel=sigmoid; total time= 1.2min
# [CV] END C=1, coef0=0.01, degree=3, gamma=scale, kernel=linear; total time=  11.2s
# [CV] END C=1, coef0=0.01, degree=3, gamma=scale, kernel=linear; total time=  10.4s
# [CV] END C=1, coef0=0.01, degree=3, gamma=scale, kernel=poly; total time=  12.0s
# [CV] END C=1, coef0=0.01, degree=3, gamma=scale, kernel=poly; total time=  12.1s
# [CV] END C=1, coef0=0.01, degree=3, gamma=scale, kernel=poly; total time=  11.5s
# [CV] END C=1, coef0=0.01, degree=3, gamma=scale, kernel=poly; total time=  11.9s
# [CV] END C=1, coef0=0.01, degree=3, gamma=scale, kernel=poly; total time=  11.0s
# [CV] END .C=1, coef0=0.01, degree=3, gamma=scale, kernel=rbf; total time=  18.5s
# [CV] END .C=1, coef0=0.01, degree=3, gamma=scale, kernel=rbf; total time=  17.1s
# [CV] END .C=1, coef0=0.01, degree=3, gamma=scale, kernel=rbf; total time=  19.2s
# [CV] END .C=1, coef0=0.01, degree=3, gamma=scale, kernel=rbf; total time=  17.9s
# [CV] END C=1, coef0=0.01, degree=3, gamma=auto, kernel=sigmoid; total time= 1.2min
# [CV] END C=1, coef0=0.01, degree=3, gamma=auto, kernel=sigmoid; total time= 1.1min
# [CV] END .C=1, coef0=0.01, degree=3, gamma=scale, kernel=rbf; total time=  15.2s
# [CV] END C=1, coef0=0.01, degree=3, gamma=auto, kernel=sigmoid; total time= 1.1min
# [CV] END C=1, coef0=0.01, degree=3, gamma=auto, kernel=sigmoid; total time= 1.2min
# [CV] END C=1, coef0=0.01, degree=8, gamma=auto, kernel=linear; total time=  10.8s
# [CV] END C=1, coef0=0.01, degree=8, gamma=auto, kernel=linear; total time=  12.3s
# [CV] END C=1, coef0=0.01, degree=8, gamma=auto, kernel=linear; total time=  10.1s
# [CV] END C=1, coef0=0.01, degree=8, gamma=auto, kernel=linear; total time=  10.6s
# [CV] END C=1, coef0=0.01, degree=8, gamma=auto, kernel=linear; total time=   9.7s
# [CV] END C=1, coef0=0.01, degree=3, gamma=scale, kernel=sigmoid; total time= 3.0min
# [CV] END C=1, coef0=0.01, degree=3, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END C=1, coef0=0.01, degree=3, gamma=scale, kernel=sigmoid; total time= 3.3min
# [CV] END C=1, coef0=0.01, degree=3, gamma=scale, kernel=sigmoid; total time= 3.4min
# [CV] END C=1, coef0=0.01, degree=3, gamma=scale, kernel=sigmoid; total time= 3.3min
# [CV] END .C=1, coef0=0.01, degree=8, gamma=auto, kernel=poly; total time= 3.0min
# [CV] END .C=1, coef0=0.01, degree=8, gamma=auto, kernel=poly; total time= 3.3min
# [CV] END .C=1, coef0=0.01, degree=8, gamma=auto, kernel=poly; total time= 3.4min
# [CV] END ..C=1, coef0=0.01, degree=8, gamma=auto, kernel=rbf; total time=  57.5s
# [CV] END ..C=1, coef0=0.01, degree=8, gamma=auto, kernel=rbf; total time=  53.8s
# [CV] END ..C=1, coef0=0.01, degree=8, gamma=auto, kernel=rbf; total time=  56.5s
# [CV] END ..C=1, coef0=0.01, degree=8, gamma=auto, kernel=rbf; total time=  56.0s
# [CV] END ..C=1, coef0=0.01, degree=8, gamma=auto, kernel=rbf; total time=  52.4s
# [CV] END C=1, coef0=0.01, degree=8, gamma=scale, kernel=linear; total time=  13.3s
# [CV] END C=1, coef0=0.01, degree=8, gamma=scale, kernel=linear; total time=  13.6s
# [CV] END C=1, coef0=0.01, degree=8, gamma=auto, kernel=sigmoid; total time= 1.2min
# [CV] END C=1, coef0=0.01, degree=8, gamma=scale, kernel=linear; total time=  10.8s
# [CV] END C=1, coef0=0.01, degree=8, gamma=scale, kernel=linear; total time=  11.5s
# [CV] END C=1, coef0=0.01, degree=8, gamma=scale, kernel=linear; total time=  10.5s
# [CV] END C=1, coef0=0.01, degree=8, gamma=auto, kernel=sigmoid; total time= 1.2min
# [CV] END C=1, coef0=0.01, degree=8, gamma=auto, kernel=sigmoid; total time= 1.3min
# [CV] END C=1, coef0=0.01, degree=8, gamma=auto, kernel=sigmoid; total time= 1.2min
# [CV] END C=1, coef0=0.01, degree=8, gamma=scale, kernel=poly; total time=  16.5s
# [CV] END C=1, coef0=0.01, degree=8, gamma=auto, kernel=sigmoid; total time= 1.2min
# [CV] END C=1, coef0=0.01, degree=8, gamma=scale, kernel=poly; total time=  17.1s
# [CV] END C=1, coef0=0.01, degree=8, gamma=scale, kernel=poly; total time=  15.1s
# [CV] END C=1, coef0=0.01, degree=8, gamma=scale, kernel=poly; total time=  18.2s
# [CV] END C=1, coef0=0.01, degree=8, gamma=scale, kernel=poly; total time=  15.8s
# [CV] END .C=1, coef0=0.01, degree=8, gamma=scale, kernel=rbf; total time=  17.0s
# [CV] END .C=1, coef0=0.01, degree=8, gamma=scale, kernel=rbf; total time=  15.2s
# [CV] END .C=1, coef0=0.01, degree=8, gamma=scale, kernel=rbf; total time=  16.8s
# [CV] END .C=1, coef0=0.01, degree=8, gamma=scale, kernel=rbf; total time=  16.1s
# [CV] END .C=1, coef0=0.01, degree=8, gamma=scale, kernel=rbf; total time=  14.7s
# [CV] END .C=1, coef0=0.01, degree=8, gamma=auto, kernel=poly; total time= 3.1min
# [CV] END .C=1, coef0=0.01, degree=8, gamma=auto, kernel=poly; total time= 3.0min
# [CV] END .C=1, coef0=10, degree=3, gamma=auto, kernel=linear; total time=  10.5s
# [CV] END .C=1, coef0=10, degree=3, gamma=auto, kernel=linear; total time=  12.1s
# [CV] END .C=1, coef0=10, degree=3, gamma=auto, kernel=linear; total time=   9.8s
# [CV] END .C=1, coef0=10, degree=3, gamma=auto, kernel=linear; total time=  10.5s
# [CV] END .C=1, coef0=10, degree=3, gamma=auto, kernel=linear; total time=   9.6s
# [CV] END ...C=1, coef0=10, degree=3, gamma=auto, kernel=poly; total time=  10.6s
# [CV] END ...C=1, coef0=10, degree=3, gamma=auto, kernel=poly; total time=  11.9s
# [CV] END ...C=1, coef0=10, degree=3, gamma=auto, kernel=poly; total time=  10.0s
# [CV] END ...C=1, coef0=10, degree=3, gamma=auto, kernel=poly; total time=  11.0s
# [CV] END ...C=1, coef0=10, degree=3, gamma=auto, kernel=poly; total time=   9.5s
# [CV] END ....C=1, coef0=10, degree=3, gamma=auto, kernel=rbf; total time=  57.2s
# [CV] END ....C=1, coef0=10, degree=3, gamma=auto, kernel=rbf; total time=  54.0s
# [CV] END ....C=1, coef0=10, degree=3, gamma=auto, kernel=rbf; total time=  56.9s
# [CV] END ....C=1, coef0=10, degree=3, gamma=auto, kernel=rbf; total time=  55.6s
# [CV] END ....C=1, coef0=10, degree=3, gamma=auto, kernel=rbf; total time=  58.5s
# [CV] END C=1, coef0=0.01, degree=8, gamma=scale, kernel=sigmoid; total time= 2.9min
# [CV] END C=1, coef0=0.01, degree=8, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=1, coef0=0.01, degree=8, gamma=scale, kernel=sigmoid; total time= 3.0min
# [CV] END C=1, coef0=0.01, degree=8, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=1, coef0=0.01, degree=8, gamma=scale, kernel=sigmoid; total time= 3.3min
# [CV] END C=1, coef0=10, degree=3, gamma=scale, kernel=linear; total time=  11.1s
# [CV] END C=1, coef0=10, degree=3, gamma=scale, kernel=linear; total time=  10.6s
# [CV] END C=1, coef0=10, degree=3, gamma=scale, kernel=linear; total time=  12.4s
# [CV] END C=1, coef0=10, degree=3, gamma=scale, kernel=linear; total time=  11.2s
# [CV] END C=1, coef0=10, degree=3, gamma=scale, kernel=linear; total time=  10.4s
# [CV] END ..C=1, coef0=10, degree=3, gamma=scale, kernel=poly; total time=  12.5s
# [CV] END ..C=1, coef0=10, degree=3, gamma=scale, kernel=poly; total time=  12.6s
# [CV] END ..C=1, coef0=10, degree=3, gamma=scale, kernel=poly; total time=  11.3s
# [CV] END ..C=1, coef0=10, degree=3, gamma=scale, kernel=poly; total time=  12.3s
# [CV] END ..C=1, coef0=10, degree=3, gamma=scale, kernel=poly; total time=  11.1s
# [CV] END ...C=1, coef0=10, degree=3, gamma=scale, kernel=rbf; total time=  18.2s
# [CV] END ...C=1, coef0=10, degree=3, gamma=scale, kernel=rbf; total time=  16.3s
# [CV] END ...C=1, coef0=10, degree=3, gamma=scale, kernel=rbf; total time=  18.3s
# [CV] END ...C=1, coef0=10, degree=3, gamma=scale, kernel=rbf; total time=  17.3s
# [CV] END ...C=1, coef0=10, degree=3, gamma=scale, kernel=rbf; total time=  16.0s
# [CV] END C=1, coef0=10, degree=3, gamma=auto, kernel=sigmoid; total time= 3.3min
# [CV] END C=1, coef0=10, degree=3, gamma=auto, kernel=sigmoid; total time= 2.9min
# [CV] END C=1, coef0=10, degree=3, gamma=auto, kernel=sigmoid; total time= 3.3min
# [CV] END C=1, coef0=10, degree=3, gamma=auto, kernel=sigmoid; total time= 3.2min
# [CV] END C=1, coef0=10, degree=3, gamma=auto, kernel=sigmoid; total time= 3.1min
# [CV] END .C=1, coef0=10, degree=8, gamma=auto, kernel=linear; total time=  10.6s
# [CV] END .C=1, coef0=10, degree=8, gamma=auto, kernel=linear; total time=  10.1s
# [CV] END .C=1, coef0=10, degree=8, gamma=auto, kernel=linear; total time=  12.2s
# [CV] END .C=1, coef0=10, degree=8, gamma=auto, kernel=linear; total time=  10.6s
# [CV] END .C=1, coef0=10, degree=8, gamma=auto, kernel=linear; total time=   9.6s
# [CV] END ...C=1, coef0=10, degree=8, gamma=auto, kernel=poly; total time=  11.2s
# [CV] END ...C=1, coef0=10, degree=8, gamma=auto, kernel=poly; total time=  11.7s
# [CV] END ...C=1, coef0=10, degree=8, gamma=auto, kernel=poly; total time=  10.0s
# [CV] END ...C=1, coef0=10, degree=8, gamma=auto, kernel=poly; total time=   9.5s
# [CV] END ...C=1, coef0=10, degree=8, gamma=auto, kernel=poly; total time=  11.1s
# [CV] END C=1, coef0=10, degree=3, gamma=scale, kernel=sigmoid; total time= 3.0min
# [CV] END C=1, coef0=10, degree=3, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END ....C=1, coef0=10, degree=8, gamma=auto, kernel=rbf; total time=  57.2s
# [CV] END ....C=1, coef0=10, degree=8, gamma=auto, kernel=rbf; total time=  54.1s
# [CV] END ....C=1, coef0=10, degree=8, gamma=auto, kernel=rbf; total time=  56.8s
# [CV] END C=1, coef0=10, degree=3, gamma=scale, kernel=sigmoid; total time= 3.3min
# [CV] END C=1, coef0=10, degree=3, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END ....C=1, coef0=10, degree=8, gamma=auto, kernel=rbf; total time=  53.6s
# [CV] END ....C=1, coef0=10, degree=8, gamma=auto, kernel=rbf; total time=  56.1s
# [CV] END C=1, coef0=10, degree=8, gamma=scale, kernel=linear; total time=  12.7s
# [CV] END C=1, coef0=10, degree=8, gamma=scale, kernel=linear; total time=  14.8s
# [CV] END C=1, coef0=10, degree=3, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END C=1, coef0=10, degree=8, gamma=scale, kernel=linear; total time=  11.5s
# [CV] END C=1, coef0=10, degree=8, gamma=scale, kernel=linear; total time=  11.9s
# [CV] END C=1, coef0=10, degree=8, gamma=scale, kernel=linear; total time=  10.4s
# [CV] END ..C=1, coef0=10, degree=8, gamma=scale, kernel=poly; total time=  15.6s
# [CV] END ..C=1, coef0=10, degree=8, gamma=scale, kernel=poly; total time=  17.6s
# [CV] END ..C=1, coef0=10, degree=8, gamma=scale, kernel=poly; total time=  14.2s
# [CV] END ..C=1, coef0=10, degree=8, gamma=scale, kernel=poly; total time=  17.3s
# [CV] END ..C=1, coef0=10, degree=8, gamma=scale, kernel=poly; total time=  15.4s
# [CV] END ...C=1, coef0=10, degree=8, gamma=scale, kernel=rbf; total time=  17.7s
# [CV] END ...C=1, coef0=10, degree=8, gamma=scale, kernel=rbf; total time=  17.7s
# [CV] END ...C=1, coef0=10, degree=8, gamma=scale, kernel=rbf; total time=  15.6s
# [CV] END ...C=1, coef0=10, degree=8, gamma=scale, kernel=rbf; total time=  16.8s
# [CV] END ...C=1, coef0=10, degree=8, gamma=scale, kernel=rbf; total time=  15.8s
# [CV] END C=1, coef0=10, degree=8, gamma=auto, kernel=sigmoid; total time= 3.0min
# [CV] END C=1, coef0=10, degree=8, gamma=auto, kernel=sigmoid; total time= 3.3min
# [CV] END C=1, coef0=10, degree=8, gamma=auto, kernel=sigmoid; total time= 3.2min
# [CV] END C=1, coef0=10, degree=8, gamma=auto, kernel=sigmoid; total time= 3.3min
# [CV] END C=1, coef0=0.5, degree=3, gamma=auto, kernel=linear; total time=  10.4s
# [CV] END C=1, coef0=0.5, degree=3, gamma=auto, kernel=linear; total time=  12.5s
# [CV] END C=1, coef0=0.5, degree=3, gamma=auto, kernel=linear; total time=   9.9s
# [CV] END C=1, coef0=10, degree=8, gamma=auto, kernel=sigmoid; total time= 3.1min
# [CV] END C=1, coef0=0.5, degree=3, gamma=auto, kernel=linear; total time=  10.6s
# [CV] END C=1, coef0=0.5, degree=3, gamma=auto, kernel=linear; total time=   9.7s
# [CV] END ..C=1, coef0=0.5, degree=3, gamma=auto, kernel=poly; total time=  56.2s
# [CV] END ..C=1, coef0=0.5, degree=3, gamma=auto, kernel=poly; total time=  56.9s
# [CV] END ..C=1, coef0=0.5, degree=3, gamma=auto, kernel=poly; total time=  53.3s
# [CV] END C=1, coef0=10, degree=8, gamma=scale, kernel=sigmoid; total time= 3.0min
# [CV] END C=1, coef0=10, degree=8, gamma=scale, kernel=sigmoid; total time= 3.3min
# [CV] END C=1, coef0=10, degree=8, gamma=scale, kernel=sigmoid; total time= 3.4min
# [CV] END ..C=1, coef0=0.5, degree=3, gamma=auto, kernel=poly; total time=  55.4s
# [CV] END ..C=1, coef0=0.5, degree=3, gamma=auto, kernel=poly; total time=  52.3s
# [CV] END ...C=1, coef0=0.5, degree=3, gamma=auto, kernel=rbf; total time=  57.6s
# [CV] END ...C=1, coef0=0.5, degree=3, gamma=auto, kernel=rbf; total time=  53.6s
# [CV] END ...C=1, coef0=0.5, degree=3, gamma=auto, kernel=rbf; total time=  56.3s
# [CV] END C=1, coef0=10, degree=8, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=1, coef0=10, degree=8, gamma=scale, kernel=sigmoid; total time= 3.0min
# [CV] END ...C=1, coef0=0.5, degree=3, gamma=auto, kernel=rbf; total time=  55.6s
# [CV] END ...C=1, coef0=0.5, degree=3, gamma=auto, kernel=rbf; total time=  52.2s
# [CV] END C=1, coef0=0.5, degree=3, gamma=scale, kernel=linear; total time=  10.9s
# [CV] END C=1, coef0=0.5, degree=3, gamma=scale, kernel=linear; total time=  13.3s
# [CV] END C=1, coef0=0.5, degree=3, gamma=scale, kernel=linear; total time=  10.8s
# [CV] END C=1, coef0=0.5, degree=3, gamma=scale, kernel=linear; total time=  11.7s
# [CV] END C=1, coef0=0.5, degree=3, gamma=scale, kernel=linear; total time=  11.8s
# [CV] END .C=1, coef0=0.5, degree=3, gamma=scale, kernel=poly; total time=  12.7s
# [CV] END .C=1, coef0=0.5, degree=3, gamma=scale, kernel=poly; total time=  12.4s
# [CV] END .C=1, coef0=0.5, degree=3, gamma=scale, kernel=poly; total time=  11.5s
# [CV] END C=1, coef0=0.5, degree=3, gamma=auto, kernel=sigmoid; total time= 1.4min
# [CV] END .C=1, coef0=0.5, degree=3, gamma=scale, kernel=poly; total time=  11.9s
# [CV] END .C=1, coef0=0.5, degree=3, gamma=scale, kernel=poly; total time=  10.8s
# [CV] END C=1, coef0=0.5, degree=3, gamma=auto, kernel=sigmoid; total time= 1.5min
# [CV] END ..C=1, coef0=0.5, degree=3, gamma=scale, kernel=rbf; total time=  17.3s
# [CV] END ..C=1, coef0=0.5, degree=3, gamma=scale, kernel=rbf; total time=  17.6s
# [CV] END ..C=1, coef0=0.5, degree=3, gamma=scale, kernel=rbf; total time=  15.6s
# [CV] END ..C=1, coef0=0.5, degree=3, gamma=scale, kernel=rbf; total time=  16.2s
# [CV] END ..C=1, coef0=0.5, degree=3, gamma=scale, kernel=rbf; total time=  14.6s
# [CV] END C=1, coef0=0.5, degree=3, gamma=auto, kernel=sigmoid; total time= 1.3min
# [CV] END C=1, coef0=0.5, degree=3, gamma=auto, kernel=sigmoid; total time= 1.4min
# [CV] END C=1, coef0=0.5, degree=3, gamma=auto, kernel=sigmoid; total time= 1.3min
# [CV] END C=1, coef0=0.5, degree=8, gamma=auto, kernel=linear; total time=  10.4s
# [CV] END C=1, coef0=0.5, degree=8, gamma=auto, kernel=linear; total time=  12.3s
# [CV] END C=1, coef0=0.5, degree=8, gamma=auto, kernel=linear; total time=  10.0s
# [CV] END C=1, coef0=0.5, degree=8, gamma=auto, kernel=linear; total time=  10.4s
# [CV] END C=1, coef0=0.5, degree=8, gamma=auto, kernel=linear; total time=   9.7s
# [CV] END ..C=1, coef0=0.5, degree=8, gamma=auto, kernel=poly; total time= 1.1min
# [CV] END ..C=1, coef0=0.5, degree=8, gamma=auto, kernel=poly; total time= 1.1min
# [CV] END ..C=1, coef0=0.5, degree=8, gamma=auto, kernel=poly; total time= 1.0min
# [CV] END ..C=1, coef0=0.5, degree=8, gamma=auto, kernel=poly; total time= 1.1min
# [CV] END ...C=1, coef0=0.5, degree=8, gamma=auto, kernel=rbf; total time=  58.7s
# [CV] END ..C=1, coef0=0.5, degree=8, gamma=auto, kernel=poly; total time=  59.9s
# [CV] END C=1, coef0=0.5, degree=3, gamma=scale, kernel=sigmoid; total time= 3.0min
# [CV] END C=1, coef0=0.5, degree=3, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=1, coef0=0.5, degree=3, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END C=1, coef0=0.5, degree=3, gamma=scale, kernel=sigmoid; total time= 3.3min
# [CV] END C=1, coef0=0.5, degree=3, gamma=scale, kernel=sigmoid; total time= 3.3min
# [CV] END ...C=1, coef0=0.5, degree=8, gamma=auto, kernel=rbf; total time=  53.8s
# [CV] END ...C=1, coef0=0.5, degree=8, gamma=auto, kernel=rbf; total time=  56.9s
# [CV] END ...C=1, coef0=0.5, degree=8, gamma=auto, kernel=rbf; total time=  56.8s
# [CV] END C=1, coef0=0.5, degree=8, gamma=scale, kernel=linear; total time=  11.3s
# [CV] END C=1, coef0=0.5, degree=8, gamma=scale, kernel=linear; total time=  13.3s
# [CV] END ...C=1, coef0=0.5, degree=8, gamma=auto, kernel=rbf; total time=  52.7s
# [CV] END C=1, coef0=0.5, degree=8, gamma=scale, kernel=linear; total time=  11.0s
# [CV] END C=1, coef0=0.5, degree=8, gamma=scale, kernel=linear; total time=  11.3s
# [CV] END C=1, coef0=0.5, degree=8, gamma=scale, kernel=linear; total time=  10.4s
# [CV] END .C=1, coef0=0.5, degree=8, gamma=scale, kernel=poly; total time=  16.9s
# [CV] END .C=1, coef0=0.5, degree=8, gamma=scale, kernel=poly; total time=  18.3s
# [CV] END .C=1, coef0=0.5, degree=8, gamma=scale, kernel=poly; total time=  14.8s
# [CV] END .C=1, coef0=0.5, degree=8, gamma=scale, kernel=poly; total time=  18.8s
# [CV] END .C=1, coef0=0.5, degree=8, gamma=scale, kernel=poly; total time=  16.4s
# [CV] END ..C=1, coef0=0.5, degree=8, gamma=scale, kernel=rbf; total time=  17.7s
# [CV] END C=1, coef0=0.5, degree=8, gamma=auto, kernel=sigmoid; total time= 1.4min
# [CV] END C=1, coef0=0.5, degree=8, gamma=auto, kernel=sigmoid; total time= 1.3min
# [CV] END C=1, coef0=0.5, degree=8, gamma=auto, kernel=sigmoid; total time= 1.5min
# [CV] END C=1, coef0=0.5, degree=8, gamma=auto, kernel=sigmoid; total time= 1.4min
# [CV] END ..C=1, coef0=0.5, degree=8, gamma=scale, kernel=rbf; total time=  16.9s
# [CV] END ..C=1, coef0=0.5, degree=8, gamma=scale, kernel=rbf; total time=  15.3s
# [CV] END C=1, coef0=0.5, degree=8, gamma=auto, kernel=sigmoid; total time= 1.3min
# [CV] END ..C=1, coef0=0.5, degree=8, gamma=scale, kernel=rbf; total time=  16.2s
# [CV] END ..C=1, coef0=0.5, degree=8, gamma=scale, kernel=rbf; total time=  14.7s
# [CV] END C=5, coef0=0.01, degree=3, gamma=auto, kernel=linear; total time=  10.2s
# [CV] END C=5, coef0=0.01, degree=3, gamma=auto, kernel=linear; total time=   9.9s
# [CV] END C=5, coef0=0.01, degree=3, gamma=auto, kernel=linear; total time=  11.8s
# [CV] END C=5, coef0=0.01, degree=3, gamma=auto, kernel=linear; total time=  10.4s
# [CV] END C=5, coef0=0.01, degree=3, gamma=auto, kernel=linear; total time=   9.5s
# [CV] END .C=5, coef0=0.01, degree=3, gamma=auto, kernel=poly; total time= 1.1min
# [CV] END .C=5, coef0=0.01, degree=3, gamma=auto, kernel=poly; total time= 1.1min
# [CV] END .C=5, coef0=0.01, degree=3, gamma=auto, kernel=poly; total time= 1.1min
# [CV] END ..C=5, coef0=0.01, degree=3, gamma=auto, kernel=rbf; total time=  25.1s
# [CV] END ..C=5, coef0=0.01, degree=3, gamma=auto, kernel=rbf; total time=  25.2s
# [CV] END .C=5, coef0=0.01, degree=3, gamma=auto, kernel=poly; total time= 1.1min
# [CV] END .C=5, coef0=0.01, degree=3, gamma=auto, kernel=poly; total time= 1.0min
# [CV] END ..C=5, coef0=0.01, degree=3, gamma=auto, kernel=rbf; total time=  24.3s
# [CV] END C=1, coef0=0.5, degree=8, gamma=scale, kernel=sigmoid; total time= 2.9min
# [CV] END ..C=5, coef0=0.01, degree=3, gamma=auto, kernel=rbf; total time=  24.9s
# [CV] END ..C=5, coef0=0.01, degree=3, gamma=auto, kernel=rbf; total time=  22.6s
# [CV] END C=1, coef0=0.5, degree=8, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=1, coef0=0.5, degree=8, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END C=1, coef0=0.5, degree=8, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=1, coef0=0.5, degree=8, gamma=scale, kernel=sigmoid; total time= 3.3min
# [CV] END C=5, coef0=0.01, degree=3, gamma=scale, kernel=linear; total time=  11.2s
# [CV] END C=5, coef0=0.01, degree=3, gamma=auto, kernel=sigmoid; total time=  33.3s
# [CV] END C=5, coef0=0.01, degree=3, gamma=scale, kernel=linear; total time=  10.2s
# [CV] END C=5, coef0=0.01, degree=3, gamma=auto, kernel=sigmoid; total time=  31.3s
# [CV] END C=5, coef0=0.01, degree=3, gamma=auto, kernel=sigmoid; total time=  31.7s
# [CV] END C=5, coef0=0.01, degree=3, gamma=scale, kernel=linear; total time=  12.1s
# [CV] END C=5, coef0=0.01, degree=3, gamma=auto, kernel=sigmoid; total time=  31.5s
# [CV] END C=5, coef0=0.01, degree=3, gamma=scale, kernel=linear; total time=  10.2s
# [CV] END C=5, coef0=0.01, degree=3, gamma=scale, kernel=linear; total time=   9.4s
# [CV] END C=5, coef0=0.01, degree=3, gamma=auto, kernel=sigmoid; total time=  30.6s
# [CV] END C=5, coef0=0.01, degree=3, gamma=scale, kernel=poly; total time=  11.0s
# [CV] END C=5, coef0=0.01, degree=3, gamma=scale, kernel=poly; total time=  10.6s
# [CV] END C=5, coef0=0.01, degree=3, gamma=scale, kernel=poly; total time=  11.1s
# [CV] END C=5, coef0=0.01, degree=3, gamma=scale, kernel=poly; total time=  10.9s
# [CV] END C=5, coef0=0.01, degree=3, gamma=scale, kernel=poly; total time=  10.0s
# [CV] END .C=5, coef0=0.01, degree=3, gamma=scale, kernel=rbf; total time=  16.5s
# [CV] END .C=5, coef0=0.01, degree=3, gamma=scale, kernel=rbf; total time=  16.5s
# [CV] END .C=5, coef0=0.01, degree=3, gamma=scale, kernel=rbf; total time=  14.8s
# [CV] END .C=5, coef0=0.01, degree=3, gamma=scale, kernel=rbf; total time=  14.8s
# [CV] END .C=5, coef0=0.01, degree=3, gamma=scale, kernel=rbf; total time=  15.5s
# [CV] END C=5, coef0=0.01, degree=8, gamma=auto, kernel=linear; total time=  10.4s
# [CV] END C=5, coef0=0.01, degree=8, gamma=auto, kernel=linear; total time=   9.9s
# [CV] END C=5, coef0=0.01, degree=8, gamma=auto, kernel=linear; total time=  11.8s
# [CV] END C=5, coef0=0.01, degree=8, gamma=auto, kernel=linear; total time=   9.7s
# [CV] END C=5, coef0=0.01, degree=8, gamma=auto, kernel=linear; total time=  10.3s
# [CV] END C=5, coef0=0.01, degree=3, gamma=scale, kernel=sigmoid; total time= 3.0min
# [CV] END C=5, coef0=0.01, degree=3, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=5, coef0=0.01, degree=3, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END C=5, coef0=0.01, degree=3, gamma=scale, kernel=sigmoid; total time= 3.3min
# [CV] END C=5, coef0=0.01, degree=3, gamma=scale, kernel=sigmoid; total time= 3.3min
# [CV] END .C=5, coef0=0.01, degree=8, gamma=auto, kernel=poly; total time= 2.9min
# [CV] END .C=5, coef0=0.01, degree=8, gamma=auto, kernel=poly; total time= 3.2min
# [CV] END ..C=5, coef0=0.01, degree=8, gamma=auto, kernel=rbf; total time=  23.9s
# [CV] END ..C=5, coef0=0.01, degree=8, gamma=auto, kernel=rbf; total time=  24.1s
# [CV] END ..C=5, coef0=0.01, degree=8, gamma=auto, kernel=rbf; total time=  23.2s
# [CV] END .C=5, coef0=0.01, degree=8, gamma=auto, kernel=poly; total time= 3.3min
# [CV] END ..C=5, coef0=0.01, degree=8, gamma=auto, kernel=rbf; total time=  23.9s
# [CV] END ..C=5, coef0=0.01, degree=8, gamma=auto, kernel=rbf; total time=  21.4s
# [CV] END C=5, coef0=0.01, degree=8, gamma=scale, kernel=linear; total time=  11.5s
# [CV] END C=5, coef0=0.01, degree=8, gamma=auto, kernel=sigmoid; total time=  32.2s
# [CV] END C=5, coef0=0.01, degree=8, gamma=auto, kernel=sigmoid; total time=  31.8s
# [CV] END C=5, coef0=0.01, degree=8, gamma=auto, kernel=sigmoid; total time=  31.7s
# [CV] END C=5, coef0=0.01, degree=8, gamma=auto, kernel=sigmoid; total time=  32.7s
# [CV] END C=5, coef0=0.01, degree=8, gamma=scale, kernel=linear; total time=  12.5s
# [CV] END C=5, coef0=0.01, degree=8, gamma=scale, kernel=linear; total time=  10.0s
# [CV] END C=5, coef0=0.01, degree=8, gamma=auto, kernel=sigmoid; total time=  31.2s
# [CV] END C=5, coef0=0.01, degree=8, gamma=scale, kernel=linear; total time=  10.7s
# [CV] END C=5, coef0=0.01, degree=8, gamma=scale, kernel=linear; total time=   9.9s
# [CV] END C=5, coef0=0.01, degree=8, gamma=scale, kernel=poly; total time=  16.2s
# [CV] END C=5, coef0=0.01, degree=8, gamma=scale, kernel=poly; total time=  16.7s
# [CV] END C=5, coef0=0.01, degree=8, gamma=scale, kernel=poly; total time=  15.0s
# [CV] END C=5, coef0=0.01, degree=8, gamma=scale, kernel=poly; total time=  16.0s
# [CV] END C=5, coef0=0.01, degree=8, gamma=scale, kernel=poly; total time=  18.2s
# [CV] END .C=5, coef0=0.01, degree=8, gamma=scale, kernel=rbf; total time=  17.1s
# [CV] END .C=5, coef0=0.01, degree=8, gamma=scale, kernel=rbf; total time=  15.1s
# [CV] END .C=5, coef0=0.01, degree=8, gamma=scale, kernel=rbf; total time=  16.8s
# [CV] END .C=5, coef0=0.01, degree=8, gamma=scale, kernel=rbf; total time=  16.4s
# [CV] END .C=5, coef0=0.01, degree=8, gamma=scale, kernel=rbf; total time=  14.7s
# [CV] END .C=5, coef0=10, degree=3, gamma=auto, kernel=linear; total time=  10.8s
# [CV] END .C=5, coef0=10, degree=3, gamma=auto, kernel=linear; total time=  12.4s
# [CV] END .C=5, coef0=10, degree=3, gamma=auto, kernel=linear; total time=  10.0s
# [CV] END .C=5, coef0=10, degree=3, gamma=auto, kernel=linear; total time=  11.0s
# [CV] END .C=5, coef0=10, degree=3, gamma=auto, kernel=linear; total time=  10.1s
# [CV] END .C=5, coef0=0.01, degree=8, gamma=auto, kernel=poly; total time= 3.0min
# [CV] END .C=5, coef0=0.01, degree=8, gamma=auto, kernel=poly; total time= 2.8min
# [CV] END ...C=5, coef0=10, degree=3, gamma=auto, kernel=poly; total time=  10.8s
# [CV] END ...C=5, coef0=10, degree=3, gamma=auto, kernel=poly; total time=  12.1s
# [CV] END ...C=5, coef0=10, degree=3, gamma=auto, kernel=poly; total time=  10.0s
# [CV] END ...C=5, coef0=10, degree=3, gamma=auto, kernel=poly; total time=  11.0s
# [CV] END ...C=5, coef0=10, degree=3, gamma=auto, kernel=poly; total time=   9.5s
# [CV] END ....C=5, coef0=10, degree=3, gamma=auto, kernel=rbf; total time=  24.5s
# [CV] END ....C=5, coef0=10, degree=3, gamma=auto, kernel=rbf; total time=  24.9s
# [CV] END ....C=5, coef0=10, degree=3, gamma=auto, kernel=rbf; total time=  23.7s
# [CV] END ....C=5, coef0=10, degree=3, gamma=auto, kernel=rbf; total time=  24.8s
# [CV] END ....C=5, coef0=10, degree=3, gamma=auto, kernel=rbf; total time=  22.7s
# [CV] END C=5, coef0=0.01, degree=8, gamma=scale, kernel=sigmoid; total time= 2.9min
# [CV] END C=5, coef0=0.01, degree=8, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=5, coef0=0.01, degree=8, gamma=scale, kernel=sigmoid; total time= 3.0min
# [CV] END C=5, coef0=0.01, degree=8, gamma=scale, kernel=sigmoid; total time= 3.3min
# [CV] END C=5, coef0=0.01, degree=8, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=5, coef0=10, degree=3, gamma=scale, kernel=linear; total time=  11.1s
# [CV] END C=5, coef0=10, degree=3, gamma=scale, kernel=linear; total time=  12.7s
# [CV] END C=5, coef0=10, degree=3, gamma=scale, kernel=linear; total time=  10.3s
# [CV] END C=5, coef0=10, degree=3, gamma=scale, kernel=linear; total time=  11.1s
# [CV] END C=5, coef0=10, degree=3, gamma=scale, kernel=linear; total time=  10.3s
# [CV] END ..C=5, coef0=10, degree=3, gamma=scale, kernel=poly; total time=  12.5s
# [CV] END ..C=5, coef0=10, degree=3, gamma=scale, kernel=poly; total time=  12.6s
# [CV] END ..C=5, coef0=10, degree=3, gamma=scale, kernel=poly; total time=  11.3s
# [CV] END ..C=5, coef0=10, degree=3, gamma=scale, kernel=poly; total time=  12.0s
# [CV] END ..C=5, coef0=10, degree=3, gamma=scale, kernel=poly; total time=  10.8s
# [CV] END ...C=5, coef0=10, degree=3, gamma=scale, kernel=rbf; total time=  17.8s
# [CV] END ...C=5, coef0=10, degree=3, gamma=scale, kernel=rbf; total time=  17.6s
# [CV] END ...C=5, coef0=10, degree=3, gamma=scale, kernel=rbf; total time=  15.6s
# [CV] END ...C=5, coef0=10, degree=3, gamma=scale, kernel=rbf; total time=  16.9s
# [CV] END ...C=5, coef0=10, degree=3, gamma=scale, kernel=rbf; total time=  16.1s
# [CV] END C=5, coef0=10, degree=3, gamma=auto, kernel=sigmoid; total time= 3.2min
# [CV] END C=5, coef0=10, degree=3, gamma=auto, kernel=sigmoid; total time= 2.9min
# [CV] END C=5, coef0=10, degree=3, gamma=auto, kernel=sigmoid; total time= 3.3min
# [CV] END .C=5, coef0=10, degree=8, gamma=auto, kernel=linear; total time=  10.8s
# [CV] END .C=5, coef0=10, degree=8, gamma=auto, kernel=linear; total time=  12.2s
# [CV] END .C=5, coef0=10, degree=8, gamma=auto, kernel=linear; total time=  10.1s
# [CV] END C=5, coef0=10, degree=3, gamma=auto, kernel=sigmoid; total time= 3.1min
# [CV] END C=5, coef0=10, degree=3, gamma=auto, kernel=sigmoid; total time= 3.2min
# [CV] END .C=5, coef0=10, degree=8, gamma=auto, kernel=linear; total time=  10.7s
# [CV] END .C=5, coef0=10, degree=8, gamma=auto, kernel=linear; total time=   9.7s
# [CV] END ...C=5, coef0=10, degree=8, gamma=auto, kernel=poly; total time=  11.2s
# [CV] END ...C=5, coef0=10, degree=8, gamma=auto, kernel=poly; total time=  11.6s
# [CV] END ...C=5, coef0=10, degree=8, gamma=auto, kernel=poly; total time=  10.1s
# [CV] END ...C=5, coef0=10, degree=8, gamma=auto, kernel=poly; total time=  11.3s
# [CV] END ...C=5, coef0=10, degree=8, gamma=auto, kernel=poly; total time=   9.4s
# [CV] END ....C=5, coef0=10, degree=8, gamma=auto, kernel=rbf; total time=  24.2s
# [CV] END ....C=5, coef0=10, degree=8, gamma=auto, kernel=rbf; total time=  24.2s
# [CV] END ....C=5, coef0=10, degree=8, gamma=auto, kernel=rbf; total time=  23.5s
# [CV] END ....C=5, coef0=10, degree=8, gamma=auto, kernel=rbf; total time=  24.8s
# [CV] END C=5, coef0=10, degree=3, gamma=scale, kernel=sigmoid; total time= 2.9min
# [CV] END C=5, coef0=10, degree=3, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END ....C=5, coef0=10, degree=8, gamma=auto, kernel=rbf; total time=  22.9s
# [CV] END C=5, coef0=10, degree=3, gamma=scale, kernel=sigmoid; total time= 3.3min
# [CV] END C=5, coef0=10, degree=8, gamma=scale, kernel=linear; total time=  11.5s
# [CV] END C=5, coef0=10, degree=8, gamma=scale, kernel=linear; total time=  13.2s
# [CV] END C=5, coef0=10, degree=3, gamma=scale, kernel=sigmoid; total time= 3.0min
# [CV] END C=5, coef0=10, degree=8, gamma=scale, kernel=linear; total time=  10.8s
# [CV] END C=5, coef0=10, degree=3, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=5, coef0=10, degree=8, gamma=scale, kernel=linear; total time=  11.3s
# [CV] END C=5, coef0=10, degree=8, gamma=scale, kernel=linear; total time=  10.4s
# [CV] END ..C=5, coef0=10, degree=8, gamma=scale, kernel=poly; total time=  15.3s
# [CV] END ..C=5, coef0=10, degree=8, gamma=scale, kernel=poly; total time=  14.1s
# [CV] END ..C=5, coef0=10, degree=8, gamma=scale, kernel=poly; total time=  17.1s
# [CV] END ..C=5, coef0=10, degree=8, gamma=scale, kernel=poly; total time=  17.1s
# [CV] END ..C=5, coef0=10, degree=8, gamma=scale, kernel=poly; total time=  15.1s
# [CV] END ...C=5, coef0=10, degree=8, gamma=scale, kernel=rbf; total time=  17.3s
# [CV] END ...C=5, coef0=10, degree=8, gamma=scale, kernel=rbf; total time=  17.5s
# [CV] END ...C=5, coef0=10, degree=8, gamma=scale, kernel=rbf; total time=  15.7s
# [CV] END ...C=5, coef0=10, degree=8, gamma=scale, kernel=rbf; total time=  16.7s
# [CV] END ...C=5, coef0=10, degree=8, gamma=scale, kernel=rbf; total time=  15.9s
# [CV] END C=5, coef0=10, degree=8, gamma=auto, kernel=sigmoid; total time= 3.2min
# [CV] END C=5, coef0=10, degree=8, gamma=auto, kernel=sigmoid; total time= 2.9min
# [CV] END C=5, coef0=10, degree=8, gamma=auto, kernel=sigmoid; total time= 3.1min
# [CV] END C=5, coef0=10, degree=8, gamma=auto, kernel=sigmoid; total time= 3.2min
# [CV] END C=5, coef0=10, degree=8, gamma=auto, kernel=sigmoid; total time= 3.3min
# [CV] END C=5, coef0=0.5, degree=3, gamma=auto, kernel=linear; total time=  10.5s
# [CV] END C=5, coef0=0.5, degree=3, gamma=auto, kernel=linear; total time=   9.9s
# [CV] END C=5, coef0=0.5, degree=3, gamma=auto, kernel=linear; total time=  11.9s
# [CV] END C=5, coef0=0.5, degree=3, gamma=auto, kernel=linear; total time=  10.7s
# [CV] END C=5, coef0=0.5, degree=3, gamma=auto, kernel=linear; total time=   9.7s
# [CV] END ..C=5, coef0=0.5, degree=3, gamma=auto, kernel=poly; total time=  21.5s
# [CV] END ..C=5, coef0=0.5, degree=3, gamma=auto, kernel=poly; total time=  22.7s
# [CV] END ..C=5, coef0=0.5, degree=3, gamma=auto, kernel=poly; total time=  21.1s
# [CV] END ..C=5, coef0=0.5, degree=3, gamma=auto, kernel=poly; total time=  20.9s
# [CV] END ..C=5, coef0=0.5, degree=3, gamma=auto, kernel=poly; total time=  23.1s
# [CV] END ...C=5, coef0=0.5, degree=3, gamma=auto, kernel=rbf; total time=  24.3s
# [CV] END ...C=5, coef0=0.5, degree=3, gamma=auto, kernel=rbf; total time=  24.1s
# [CV] END ...C=5, coef0=0.5, degree=3, gamma=auto, kernel=rbf; total time=  23.5s
# [CV] END ...C=5, coef0=0.5, degree=3, gamma=auto, kernel=rbf; total time=  25.0s
# [CV] END ...C=5, coef0=0.5, degree=3, gamma=auto, kernel=rbf; total time=  22.8s
# [CV] END C=5, coef0=10, degree=8, gamma=scale, kernel=sigmoid; total time= 2.9min
# [CV] END C=5, coef0=10, degree=8, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=5, coef0=10, degree=8, gamma=scale, kernel=sigmoid; total time= 3.3min
# [CV] END C=5, coef0=0.5, degree=3, gamma=auto, kernel=sigmoid; total time=  42.8s
# [CV] END C=5, coef0=0.5, degree=3, gamma=scale, kernel=linear; total time=  11.6s
# [CV] END C=5, coef0=0.5, degree=3, gamma=auto, kernel=sigmoid; total time=  43.6s
# [CV] END C=5, coef0=0.5, degree=3, gamma=scale, kernel=linear; total time=  12.9s
# [CV] END C=5, coef0=0.5, degree=3, gamma=scale, kernel=linear; total time=  10.5s
# [CV] END C=5, coef0=0.5, degree=3, gamma=auto, kernel=sigmoid; total time=  41.1s
# [CV] END C=5, coef0=0.5, degree=3, gamma=scale, kernel=linear; total time=  11.2s
# [CV] END C=5, coef0=0.5, degree=3, gamma=scale, kernel=linear; total time=  10.3s
# [CV] END C=5, coef0=0.5, degree=3, gamma=auto, kernel=sigmoid; total time=  43.0s
# [CV] END C=5, coef0=0.5, degree=3, gamma=auto, kernel=sigmoid; total time=  40.9s
# [CV] END .C=5, coef0=0.5, degree=3, gamma=scale, kernel=poly; total time=  11.8s
# [CV] END .C=5, coef0=0.5, degree=3, gamma=scale, kernel=poly; total time=  12.1s
# [CV] END .C=5, coef0=0.5, degree=3, gamma=scale, kernel=poly; total time=  11.1s
# [CV] END .C=5, coef0=0.5, degree=3, gamma=scale, kernel=poly; total time=  10.6s
# [CV] END .C=5, coef0=0.5, degree=3, gamma=scale, kernel=poly; total time=  11.2s
# [CV] END C=5, coef0=10, degree=8, gamma=scale, kernel=sigmoid; total time= 3.0min
# [CV] END ..C=5, coef0=0.5, degree=3, gamma=scale, kernel=rbf; total time=  16.5s
# [CV] END C=5, coef0=10, degree=8, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END ..C=5, coef0=0.5, degree=3, gamma=scale, kernel=rbf; total time=  16.8s
# [CV] END ..C=5, coef0=0.5, degree=3, gamma=scale, kernel=rbf; total time=  14.9s
# [CV] END ..C=5, coef0=0.5, degree=3, gamma=scale, kernel=rbf; total time=  14.8s
# [CV] END ..C=5, coef0=0.5, degree=3, gamma=scale, kernel=rbf; total time=  15.7s
# [CV] END C=5, coef0=0.5, degree=8, gamma=auto, kernel=linear; total time=  10.5s
# [CV] END C=5, coef0=0.5, degree=8, gamma=auto, kernel=linear; total time=   9.9s
# [CV] END C=5, coef0=0.5, degree=8, gamma=auto, kernel=linear; total time=  11.7s
# [CV] END C=5, coef0=0.5, degree=8, gamma=auto, kernel=linear; total time=  10.5s
# [CV] END C=5, coef0=0.5, degree=8, gamma=auto, kernel=linear; total time=   9.8s
# [CV] END ..C=5, coef0=0.5, degree=8, gamma=auto, kernel=poly; total time=  27.8s
# [CV] END ..C=5, coef0=0.5, degree=8, gamma=auto, kernel=poly; total time=  26.3s
# [CV] END ..C=5, coef0=0.5, degree=8, gamma=auto, kernel=poly; total time=  27.0s
# [CV] END ..C=5, coef0=0.5, degree=8, gamma=auto, kernel=poly; total time=  26.3s
# [CV] END ..C=5, coef0=0.5, degree=8, gamma=auto, kernel=poly; total time=  23.8s
# [CV] END ...C=5, coef0=0.5, degree=8, gamma=auto, kernel=rbf; total time=  23.7s
# [CV] END ...C=5, coef0=0.5, degree=8, gamma=auto, kernel=rbf; total time=  24.1s
# [CV] END ...C=5, coef0=0.5, degree=8, gamma=auto, kernel=rbf; total time=  23.1s
# [CV] END ...C=5, coef0=0.5, degree=8, gamma=auto, kernel=rbf; total time=  24.0s
# [CV] END ...C=5, coef0=0.5, degree=8, gamma=auto, kernel=rbf; total time=  22.2s
# [CV] END C=5, coef0=0.5, degree=8, gamma=auto, kernel=sigmoid; total time=  42.6s
# [CV] END C=5, coef0=0.5, degree=8, gamma=auto, kernel=sigmoid; total time=  43.2s
# [CV] END C=5, coef0=0.5, degree=8, gamma=auto, kernel=sigmoid; total time=  41.6s
# [CV] END C=5, coef0=0.5, degree=3, gamma=scale, kernel=sigmoid; total time= 2.8min
# [CV] END C=5, coef0=0.5, degree=8, gamma=scale, kernel=linear; total time=  11.2s
# [CV] END C=5, coef0=0.5, degree=3, gamma=scale, kernel=sigmoid; total time= 3.0min
# [CV] END C=5, coef0=0.5, degree=3, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END C=5, coef0=0.5, degree=8, gamma=scale, kernel=linear; total time=  12.3s
# [CV] END C=5, coef0=0.5, degree=8, gamma=scale, kernel=linear; total time=  10.2s
# [CV] END C=5, coef0=0.5, degree=3, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END C=5, coef0=0.5, degree=8, gamma=auto, kernel=sigmoid; total time=  40.4s
# [CV] END C=5, coef0=0.5, degree=8, gamma=auto, kernel=sigmoid; total time=  42.9s
# [CV] END C=5, coef0=0.5, degree=3, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=5, coef0=0.5, degree=8, gamma=scale, kernel=linear; total time=   9.5s
# [CV] END C=5, coef0=0.5, degree=8, gamma=scale, kernel=linear; total time=  10.1s
# [CV] END .C=5, coef0=0.5, degree=8, gamma=scale, kernel=poly; total time=  15.7s
# [CV] END .C=5, coef0=0.5, degree=8, gamma=scale, kernel=poly; total time=  16.3s
# [CV] END .C=5, coef0=0.5, degree=8, gamma=scale, kernel=poly; total time=  13.4s
# [CV] END .C=5, coef0=0.5, degree=8, gamma=scale, kernel=poly; total time=  15.4s
# [CV] END .C=5, coef0=0.5, degree=8, gamma=scale, kernel=poly; total time=  16.5s
# [CV] END ..C=5, coef0=0.5, degree=8, gamma=scale, kernel=rbf; total time=  15.0s
# [CV] END ..C=5, coef0=0.5, degree=8, gamma=scale, kernel=rbf; total time=  16.7s
# [CV] END ..C=5, coef0=0.5, degree=8, gamma=scale, kernel=rbf; total time=  16.4s
# [CV] END ..C=5, coef0=0.5, degree=8, gamma=scale, kernel=rbf; total time=  15.4s
# [CV] END ..C=5, coef0=0.5, degree=8, gamma=scale, kernel=rbf; total time=  13.9s
# [CV] END C=10, coef0=0.01, degree=3, gamma=auto, kernel=linear; total time=   9.5s
# [CV] END C=10, coef0=0.01, degree=3, gamma=auto, kernel=linear; total time=   9.7s
# [CV] END C=10, coef0=0.01, degree=3, gamma=auto, kernel=linear; total time=  11.7s
# [CV] END C=10, coef0=0.01, degree=3, gamma=auto, kernel=linear; total time=  10.2s
# [CV] END C=10, coef0=0.01, degree=3, gamma=auto, kernel=linear; total time=   9.3s
# [CV] END C=10, coef0=0.01, degree=3, gamma=auto, kernel=poly; total time=  46.8s
# [CV] END C=10, coef0=0.01, degree=3, gamma=auto, kernel=poly; total time=  48.2s
# [CV] END C=10, coef0=0.01, degree=3, gamma=auto, kernel=poly; total time=  45.0s
# [CV] END .C=10, coef0=0.01, degree=3, gamma=auto, kernel=rbf; total time=  16.6s
# [CV] END .C=10, coef0=0.01, degree=3, gamma=auto, kernel=rbf; total time=  17.3s
# [CV] END C=10, coef0=0.01, degree=3, gamma=auto, kernel=poly; total time=  43.9s
# [CV] END C=10, coef0=0.01, degree=3, gamma=auto, kernel=poly; total time=  47.6s
# [CV] END .C=10, coef0=0.01, degree=3, gamma=auto, kernel=rbf; total time=  17.6s
# [CV] END .C=10, coef0=0.01, degree=3, gamma=auto, kernel=rbf; total time=  17.2s
# [CV] END .C=10, coef0=0.01, degree=3, gamma=auto, kernel=rbf; total time=  16.3s
# [CV] END C=10, coef0=0.01, degree=3, gamma=auto, kernel=sigmoid; total time=  21.1s
# [CV] END C=10, coef0=0.01, degree=3, gamma=auto, kernel=sigmoid; total time=  21.2s
# [CV] END C=10, coef0=0.01, degree=3, gamma=auto, kernel=sigmoid; total time=  21.5s
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=linear; total time=  10.9s
# [CV] END C=5, coef0=0.5, degree=8, gamma=scale, kernel=sigmoid; total time= 2.8min
# [CV] END C=10, coef0=0.01, degree=3, gamma=auto, kernel=sigmoid; total time=  22.1s
# [CV] END C=10, coef0=0.01, degree=3, gamma=auto, kernel=sigmoid; total time=  19.2s
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=linear; total time=  12.4s
# [CV] END C=5, coef0=0.5, degree=8, gamma=scale, kernel=sigmoid; total time= 3.0min
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=linear; total time=   9.8s
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=linear; total time=  10.6s
# [CV] END C=5, coef0=0.5, degree=8, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=linear; total time=   9.8s
# [CV] END C=5, coef0=0.5, degree=8, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=poly; total time=  11.2s
# [CV] END C=5, coef0=0.5, degree=8, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=poly; total time=  10.6s
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=poly; total time=  11.2s
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=poly; total time=  10.0s
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=poly; total time=  10.7s
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=rbf; total time=  16.2s
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=rbf; total time=  16.1s
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=rbf; total time=  14.4s
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=rbf; total time=  14.3s
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=rbf; total time=  15.3s
# [CV] END C=10, coef0=0.01, degree=8, gamma=auto, kernel=linear; total time=   9.7s
# [CV] END C=10, coef0=0.01, degree=8, gamma=auto, kernel=linear; total time=   9.5s
# [CV] END C=10, coef0=0.01, degree=8, gamma=auto, kernel=linear; total time=  11.5s
# [CV] END C=10, coef0=0.01, degree=8, gamma=auto, kernel=linear; total time=  10.2s
# [CV] END C=10, coef0=0.01, degree=8, gamma=auto, kernel=linear; total time=   9.5s
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=sigmoid; total time= 2.9min
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=sigmoid; total time= 3.0min
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=sigmoid; total time= 3.3min
# [CV] END C=10, coef0=0.01, degree=3, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=10, coef0=0.01, degree=8, gamma=auto, kernel=poly; total time= 2.8min
# [CV] END C=10, coef0=0.01, degree=8, gamma=auto, kernel=poly; total time= 3.0min
# [CV] END .C=10, coef0=0.01, degree=8, gamma=auto, kernel=rbf; total time=  16.0s
# [CV] END .C=10, coef0=0.01, degree=8, gamma=auto, kernel=rbf; total time=  16.3s
# [CV] END .C=10, coef0=0.01, degree=8, gamma=auto, kernel=rbf; total time=  15.6s
# [CV] END .C=10, coef0=0.01, degree=8, gamma=auto, kernel=rbf; total time=  15.7s
# [CV] END C=10, coef0=0.01, degree=8, gamma=auto, kernel=poly; total time= 3.1min
# [CV] END .C=10, coef0=0.01, degree=8, gamma=auto, kernel=rbf; total time=  14.0s
# [CV] END C=10, coef0=0.01, degree=8, gamma=auto, kernel=sigmoid; total time=  19.8s
# [CV] END C=10, coef0=0.01, degree=8, gamma=auto, kernel=sigmoid; total time=  19.9s
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=linear; total time=  10.7s
# [CV] END C=10, coef0=0.01, degree=8, gamma=auto, kernel=sigmoid; total time=  19.3s
# [CV] END C=10, coef0=0.01, degree=8, gamma=auto, kernel=sigmoid; total time=  18.5s
# [CV] END C=10, coef0=0.01, degree=8, gamma=auto, kernel=sigmoid; total time=  21.0s
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=linear; total time=  11.2s
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=linear; total time=   9.2s
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=linear; total time=   9.9s
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=linear; total time=   9.1s
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=poly; total time=  15.7s
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=poly; total time=  16.4s
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=poly; total time=  14.6s
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=poly; total time=  15.6s
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=poly; total time=  17.4s
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=rbf; total time=  16.7s
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=rbf; total time=  16.5s
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=rbf; total time=  14.6s
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=rbf; total time=  15.5s
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=rbf; total time=  14.3s
# [CV] END C=10, coef0=10, degree=3, gamma=auto, kernel=linear; total time=  10.4s
# [CV] END C=10, coef0=10, degree=3, gamma=auto, kernel=linear; total time=  12.1s
# [CV] END C=10, coef0=10, degree=3, gamma=auto, kernel=linear; total time=   9.9s
# [CV] END C=10, coef0=10, degree=3, gamma=auto, kernel=linear; total time=  10.6s
# [CV] END C=10, coef0=10, degree=3, gamma=auto, kernel=linear; total time=   9.8s
# [CV] END ..C=10, coef0=10, degree=3, gamma=auto, kernel=poly; total time=  10.8s
# [CV] END C=10, coef0=0.01, degree=8, gamma=auto, kernel=poly; total time= 2.9min
# [CV] END ..C=10, coef0=10, degree=3, gamma=auto, kernel=poly; total time=  11.9s
# [CV] END C=10, coef0=0.01, degree=8, gamma=auto, kernel=poly; total time= 2.7min
# [CV] END ..C=10, coef0=10, degree=3, gamma=auto, kernel=poly; total time=   9.8s
# [CV] END ..C=10, coef0=10, degree=3, gamma=auto, kernel=poly; total time=   9.4s
# [CV] END ..C=10, coef0=10, degree=3, gamma=auto, kernel=poly; total time=  10.6s
# [CV] END ...C=10, coef0=10, degree=3, gamma=auto, kernel=rbf; total time=  16.1s
# [CV] END ...C=10, coef0=10, degree=3, gamma=auto, kernel=rbf; total time=  16.7s
# [CV] END ...C=10, coef0=10, degree=3, gamma=auto, kernel=rbf; total time=  16.4s
# [CV] END ...C=10, coef0=10, degree=3, gamma=auto, kernel=rbf; total time=  16.3s
# [CV] END ...C=10, coef0=10, degree=3, gamma=auto, kernel=rbf; total time=  15.0s
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=sigmoid; total time= 2.8min
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=sigmoid; total time= 3.0min
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=10, coef0=0.01, degree=8, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END C=10, coef0=10, degree=3, gamma=scale, kernel=linear; total time=  10.9s
# [CV] END C=10, coef0=10, degree=3, gamma=scale, kernel=linear; total time=  12.5s
# [CV] END C=10, coef0=10, degree=3, gamma=scale, kernel=linear; total time=  10.1s
# [CV] END C=10, coef0=10, degree=3, gamma=scale, kernel=linear; total time=  10.9s
# [CV] END C=10, coef0=10, degree=3, gamma=scale, kernel=linear; total time=  10.0s
# [CV] END .C=10, coef0=10, degree=3, gamma=scale, kernel=poly; total time=  12.3s
# [CV] END .C=10, coef0=10, degree=3, gamma=scale, kernel=poly; total time=  12.4s
# [CV] END .C=10, coef0=10, degree=3, gamma=scale, kernel=poly; total time=  11.1s
# [CV] END .C=10, coef0=10, degree=3, gamma=scale, kernel=poly; total time=  11.6s
# [CV] END .C=10, coef0=10, degree=3, gamma=scale, kernel=poly; total time=  10.2s
# [CV] END ..C=10, coef0=10, degree=3, gamma=scale, kernel=rbf; total time=  17.1s
# [CV] END ..C=10, coef0=10, degree=3, gamma=scale, kernel=rbf; total time=  17.1s
# [CV] END ..C=10, coef0=10, degree=3, gamma=scale, kernel=rbf; total time=  14.8s
# [CV] END ..C=10, coef0=10, degree=3, gamma=scale, kernel=rbf; total time=  16.2s
# [CV] END ..C=10, coef0=10, degree=3, gamma=scale, kernel=rbf; total time=  15.3s
# [CV] END C=10, coef0=10, degree=3, gamma=auto, kernel=sigmoid; total time= 2.9min
# [CV] END C=10, coef0=10, degree=3, gamma=auto, kernel=sigmoid; total time= 3.2min
# [CV] END C=10, coef0=10, degree=3, gamma=auto, kernel=sigmoid; total time= 3.3min
# [CV] END C=10, coef0=10, degree=8, gamma=auto, kernel=linear; total time=  10.4s
# [CV] END C=10, coef0=10, degree=8, gamma=auto, kernel=linear; total time=  12.0s
# [CV] END C=10, coef0=10, degree=8, gamma=auto, kernel=linear; total time=   9.8s
# [CV] END C=10, coef0=10, degree=3, gamma=auto, kernel=sigmoid; total time= 3.0min
# [CV] END C=10, coef0=10, degree=8, gamma=auto, kernel=linear; total time=  10.5s
# [CV] END C=10, coef0=10, degree=3, gamma=auto, kernel=sigmoid; total time= 3.1min
# [CV] END C=10, coef0=10, degree=8, gamma=auto, kernel=linear; total time=   9.5s
# [CV] END ..C=10, coef0=10, degree=8, gamma=auto, kernel=poly; total time=  10.9s
# [CV] END ..C=10, coef0=10, degree=8, gamma=auto, kernel=poly; total time=  11.5s
# [CV] END ..C=10, coef0=10, degree=8, gamma=auto, kernel=poly; total time=   9.7s
# [CV] END ..C=10, coef0=10, degree=8, gamma=auto, kernel=poly; total time=  10.8s
# [CV] END ..C=10, coef0=10, degree=8, gamma=auto, kernel=poly; total time=   9.1s
# [CV] END ...C=10, coef0=10, degree=8, gamma=auto, kernel=rbf; total time=  16.1s
# [CV] END ...C=10, coef0=10, degree=8, gamma=auto, kernel=rbf; total time=  16.6s
# [CV] END ...C=10, coef0=10, degree=8, gamma=auto, kernel=rbf; total time=  16.2s
# [CV] END ...C=10, coef0=10, degree=8, gamma=auto, kernel=rbf; total time=  16.1s
# [CV] END ...C=10, coef0=10, degree=8, gamma=auto, kernel=rbf; total time=  15.1s
# [CV] END C=10, coef0=10, degree=3, gamma=scale, kernel=sigmoid; total time= 2.9min
# [CV] END C=10, coef0=10, degree=3, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END C=10, coef0=10, degree=3, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=10, coef0=10, degree=8, gamma=scale, kernel=linear; total time=  11.1s
# [CV] END C=10, coef0=10, degree=8, gamma=scale, kernel=linear; total time=  12.9s
# [CV] END C=10, coef0=10, degree=3, gamma=scale, kernel=sigmoid; total time= 3.0min
# [CV] END C=10, coef0=10, degree=8, gamma=scale, kernel=linear; total time=  11.0s
# [CV] END C=10, coef0=10, degree=3, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END C=10, coef0=10, degree=8, gamma=scale, kernel=linear; total time=  10.9s
# [CV] END C=10, coef0=10, degree=8, gamma=scale, kernel=linear; total time=  10.1s
# [CV] END .C=10, coef0=10, degree=8, gamma=scale, kernel=poly; total time=  15.0s
# [CV] END .C=10, coef0=10, degree=8, gamma=scale, kernel=poly; total time=  16.8s
# [CV] END .C=10, coef0=10, degree=8, gamma=scale, kernel=poly; total time=  13.6s
# [CV] END .C=10, coef0=10, degree=8, gamma=scale, kernel=poly; total time=  16.5s
# [CV] END .C=10, coef0=10, degree=8, gamma=scale, kernel=poly; total time=  14.8s
# [CV] END ..C=10, coef0=10, degree=8, gamma=scale, kernel=rbf; total time=  17.0s
# [CV] END ..C=10, coef0=10, degree=8, gamma=scale, kernel=rbf; total time=  17.3s
# [CV] END ..C=10, coef0=10, degree=8, gamma=scale, kernel=rbf; total time=  14.9s
# [CV] END ..C=10, coef0=10, degree=8, gamma=scale, kernel=rbf; total time=  16.2s
# [CV] END ..C=10, coef0=10, degree=8, gamma=scale, kernel=rbf; total time=  15.5s
# [CV] END C=10, coef0=10, degree=8, gamma=auto, kernel=sigmoid; total time= 2.9min
# [CV] END C=10, coef0=10, degree=8, gamma=auto, kernel=sigmoid; total time= 3.2min
# [CV] END C=10, coef0=10, degree=8, gamma=auto, kernel=sigmoid; total time= 3.3min
# [CV] END C=10, coef0=10, degree=8, gamma=auto, kernel=sigmoid; total time= 3.0min
# [CV] END C=10, coef0=0.5, degree=3, gamma=auto, kernel=linear; total time=  10.3s
# [CV] END C=10, coef0=10, degree=8, gamma=auto, kernel=sigmoid; total time= 3.2min
# [CV] END C=10, coef0=0.5, degree=3, gamma=auto, kernel=linear; total time=  11.8s
# [CV] END C=10, coef0=0.5, degree=3, gamma=auto, kernel=linear; total time=   9.7s
# [CV] END C=10, coef0=0.5, degree=3, gamma=auto, kernel=linear; total time=  10.3s
# [CV] END C=10, coef0=0.5, degree=3, gamma=auto, kernel=linear; total time=   9.4s
# [CV] END .C=10, coef0=0.5, degree=3, gamma=auto, kernel=poly; total time=  15.3s
# [CV] END .C=10, coef0=0.5, degree=3, gamma=auto, kernel=poly; total time=  15.7s
# [CV] END .C=10, coef0=0.5, degree=3, gamma=auto, kernel=poly; total time=  15.4s
# [CV] END .C=10, coef0=0.5, degree=3, gamma=auto, kernel=poly; total time=  16.8s
# [CV] END .C=10, coef0=0.5, degree=3, gamma=auto, kernel=poly; total time=  15.3s
# [CV] END ..C=10, coef0=0.5, degree=3, gamma=auto, kernel=rbf; total time=  16.0s
# [CV] END ..C=10, coef0=0.5, degree=3, gamma=auto, kernel=rbf; total time=  16.8s
# [CV] END ..C=10, coef0=0.5, degree=3, gamma=auto, kernel=rbf; total time=  16.3s
# [CV] END ..C=10, coef0=0.5, degree=3, gamma=auto, kernel=rbf; total time=  16.2s
# [CV] END ..C=10, coef0=0.5, degree=3, gamma=auto, kernel=rbf; total time=  15.2s
# [CV] END C=10, coef0=0.5, degree=3, gamma=auto, kernel=sigmoid; total time=  28.9s
# [CV] END C=10, coef0=0.5, degree=3, gamma=auto, kernel=sigmoid; total time=  27.8s
# [CV] END C=10, coef0=10, degree=8, gamma=scale, kernel=sigmoid; total time= 2.8min
# [CV] END C=10, coef0=0.5, degree=3, gamma=auto, kernel=sigmoid; total time=  28.1s
# [CV] END C=10, coef0=10, degree=8, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END C=10, coef0=0.5, degree=3, gamma=scale, kernel=linear; total time=  10.9s
# [CV] END C=10, coef0=10, degree=8, gamma=scale, kernel=sigmoid; total time= 3.2min
# [CV] END C=10, coef0=0.5, degree=3, gamma=scale, kernel=linear; total time=  12.3s
# [CV] END C=10, coef0=0.5, degree=3, gamma=scale, kernel=linear; total time=  10.1s
# [CV] END C=10, coef0=0.5, degree=3, gamma=auto, kernel=sigmoid; total time=  26.7s
# [CV] END C=10, coef0=0.5, degree=3, gamma=auto, kernel=sigmoid; total time=  25.0s
# [CV] END C=10, coef0=0.5, degree=3, gamma=scale, kernel=linear; total time=  10.2s
# [CV] END C=10, coef0=0.5, degree=3, gamma=scale, kernel=linear; total time=   9.6s
# [CV] END C=10, coef0=0.5, degree=3, gamma=scale, kernel=poly; total time=  10.8s
# [CV] END C=10, coef0=0.5, degree=3, gamma=scale, kernel=poly; total time=  11.1s
# [CV] END C=10, coef0=0.5, degree=3, gamma=scale, kernel=poly; total time=  10.7s
# [CV] END C=10, coef0=0.5, degree=3, gamma=scale, kernel=poly; total time=  11.1s
# [CV] END C=10, coef0=0.5, degree=3, gamma=scale, kernel=poly; total time=   9.9s
# [CV] END .C=10, coef0=0.5, degree=3, gamma=scale, kernel=rbf; total time=  16.4s
# [CV] END .C=10, coef0=0.5, degree=3, gamma=scale, kernel=rbf; total time=  15.0s
# [CV] END .C=10, coef0=0.5, degree=3, gamma=scale, kernel=rbf; total time=  16.5s
# [CV] END .C=10, coef0=0.5, degree=3, gamma=scale, kernel=rbf; total time=  16.0s
# [CV] END .C=10, coef0=0.5, degree=3, gamma=scale, kernel=rbf; total time=  14.7s
# [CV] END C=10, coef0=10, degree=8, gamma=scale, kernel=sigmoid; total time= 2.9min
# [CV] END C=10, coef0=10, degree=8, gamma=scale, kernel=sigmoid; total time= 3.0min
# [CV] END C=10, coef0=0.5, degree=8, gamma=auto, kernel=linear; total time=  10.2s
# [CV] END C=10, coef0=0.5, degree=8, gamma=auto, kernel=linear; total time=  11.8s
# [CV] END C=10, coef0=0.5, degree=8, gamma=auto, kernel=linear; total time=   9.4s
# [CV] END C=10, coef0=0.5, degree=8, gamma=auto, kernel=linear; total time=  10.2s
# [CV] END C=10, coef0=0.5, degree=8, gamma=auto, kernel=linear; total time=   9.5s
# [CV] END .C=10, coef0=0.5, degree=8, gamma=auto, kernel=poly; total time=  17.6s
# [CV] END .C=10, coef0=0.5, degree=8, gamma=auto, kernel=poly; total time=  18.7s
# [CV] END .C=10, coef0=0.5, degree=8, gamma=auto, kernel=poly; total time=  17.9s
# [CV] END .C=10, coef0=0.5, degree=8, gamma=auto, kernel=poly; total time=  18.0s
# [CV] END .C=10, coef0=0.5, degree=8, gamma=auto, kernel=poly; total time=  16.9s
# [CV] END ..C=10, coef0=0.5, degree=8, gamma=auto, kernel=rbf; total time=  16.2s
# [CV] END ..C=10, coef0=0.5, degree=8, gamma=auto, kernel=rbf; total time=  16.7s
# [CV] END ..C=10, coef0=0.5, degree=8, gamma=auto, kernel=rbf; total time=  16.1s
# [CV] END ..C=10, coef0=0.5, degree=8, gamma=auto, kernel=rbf; total time=  16.5s
# [CV] END ..C=10, coef0=0.5, degree=8, gamma=auto, kernel=rbf; total time=  15.1s
# [CV] END C=10, coef0=0.5, degree=8, gamma=auto, kernel=sigmoid; total time=  28.3s
# [CV] END C=10, coef0=0.5, degree=8, gamma=auto, kernel=sigmoid; total time=  29.4s
# [CV] END C=10, coef0=0.5, degree=8, gamma=auto, kernel=sigmoid; total time=  28.6s
# [CV] END C=10, coef0=0.5, degree=8, gamma=scale, kernel=linear; total time=  11.3s
# [CV] END C=10, coef0=0.5, degree=8, gamma=auto, kernel=sigmoid; total time=  27.3s
# [CV] END C=10, coef0=0.5, degree=8, gamma=auto, kernel=sigmoid; total time=  28.0s
# [CV] END C=10, coef0=0.5, degree=8, gamma=scale, kernel=linear; total time=  12.5s
# [CV] END C=10, coef0=0.5, degree=8, gamma=scale, kernel=linear; total time=  10.3s
# [CV] END C=10, coef0=0.5, degree=8, gamma=scale, kernel=linear; total time=  10.8s
# [CV] END C=10, coef0=0.5, degree=8, gamma=scale, kernel=linear; total time=  10.1s
# [CV] END C=10, coef0=0.5, degree=8, gamma=scale, kernel=poly; total time=  16.5s
# [CV] END C=10, coef0=0.5, degree=8, gamma=scale, kernel=poly; total time=  17.0s
# [CV] END C=10, coef0=0.5, degree=8, gamma=scale, kernel=poly; total time=  14.1s
# [CV] END C=10, coef0=0.5, degree=3, gamma=scale, kernel=sigmoid; total time= 2.8min
# [CV] END C=10, coef0=0.5, degree=3, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END C=10, coef0=0.5, degree=8, gamma=scale, kernel=poly; total time=  15.9s
# [CV] END C=10, coef0=0.5, degree=8, gamma=scale, kernel=poly; total time=  17.6s
# [CV] END C=10, coef0=0.5, degree=3, gamma=scale, kernel=sigmoid; total time= 2.9min
# [CV] END .C=10, coef0=0.5, degree=8, gamma=scale, kernel=rbf; total time=  16.7s
# [CV] END C=10, coef0=0.5, degree=3, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END .C=10, coef0=0.5, degree=8, gamma=scale, kernel=rbf; total time=  16.8s
# [CV] END C=10, coef0=0.5, degree=3, gamma=scale, kernel=sigmoid; total time= 3.1min
# [CV] END .C=10, coef0=0.5, degree=8, gamma=scale, kernel=rbf; total time=  14.4s
# [CV] END .C=10, coef0=0.5, degree=8, gamma=scale, kernel=rbf; total time=  14.2s
# [CV] END .C=10, coef0=0.5, degree=8, gamma=scale, kernel=rbf; total time=  14.9s
# [CV] END C=10, coef0=0.5, degree=8, gamma=scale, kernel=sigmoid; total time= 1.8min
# [CV] END C=10, coef0=0.5, degree=8, gamma=scale, kernel=sigmoid; total time= 2.0min
# [CV] END C=10, coef0=0.5, degree=8, gamma=scale, kernel=sigmoid; total time= 1.8min
# [CV] END C=10, coef0=0.5, degree=8, gamma=scale, kernel=sigmoid; total time= 1.9min
# [CV] END C=10, coef0=0.5, degree=8, gamma=scale, kernel=sigmoid; total time= 2.0min
# Mejor Estimator:  SVR(C=10, coef0=0.01, gamma='auto', kernel='poly')
# Mejores Parametros:  {'C': 10, 'coef0': 0.01, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}

# %%
model  = grid.best_estimator_

# %%
model.fit(x_train, y_train)
# Out:
# SVR(C=10, coef0=0.5, gamma='auto', kernel='sigmoid')

# %% [markdown]
# ## **testeo**

# %%
def rollingWindowPrediction_SVR(model, x_test, steps=50):
    output = []
    N = x_test.shape[-1]

    for elem in tqdm(x_test):
        elem = elem.reshape(1, -1)
        #print(elem)
        test_aux = []
        count = 0
        while count < steps:
            #print(count)
            pred = model.predict(elem)
            test_aux.append(pred[0])
            elem = np.append(elem, pred)[1:].reshape(1,-1)
            #print(elem.shape)
            count += 1

        output.append(test_aux)
    return output

# %%
import pickle
# save the model to disk
filename = 'SVR_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
import pickle
filename = 'SVR_model.sav'
# load model
model = pickle.load(open(filename, 'rb'))

# %%
test_pred = rollingWindowPrediction_SVR(model, x_test, steps = 50)
# Out:
# 100%|██████████| 2000/2000 [00:35<00:00, 55.98it/s]

# %%
i = 65

plt.plot(test_pred[i],'-+', label='Prediction')
plt.plot(y_test[i:i+50], '-*',label='Real')
plt.legend()
plt.show()

# %%
import errores as er
x = er.error_metrics(test_pred[:-49], test_scaled[:3000], 50)
# Out:
# Mean Squared Error: 0.004861099936160618
# Mean Absolute Percentage Error: 0.1098413447857223
# R2 Score: -3.534811477686931
# Root Mean Squared Error: 0.0673149129864469
